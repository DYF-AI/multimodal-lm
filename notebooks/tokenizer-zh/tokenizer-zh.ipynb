# %% [markdown]
# ### 1.动机
# - donut使用了多语言的词表, 实际使用中大多情况下都是只有中文和英文词表

# %% [markdown]
# ### 2.bloom模型

# %%
from tqdm import tqdm
from transformers import AutoTokenizer
from vocabulary_pruner import VocabularyPruner, DonutVocabularyPruner

# %%
MP1 = "J:/model/bigscience-bloom-560m"
MP2 = "J:/model/YeungNLP-bloom-396m-zh"

# %%
class BloomVocabularyPruner(VocabularyPruner):

    def update_ebeddings(self, model, new2old_token_id, new_embeds, new_lm_head):
        for token_id, old_token_id in tqdm(new2old_token_id.items()):
            new_embeds.weight.data[token_id] = model.transformer.word_embeddings.weight.data[old_token_id]
            new_lm_head.weight.data[token_id] = model.lm_head.weight.data[old_token_id]
        model.transformer.word_embeddings.weight = new_embeds.weight
        model.lm_head.weight = new_lm_head.weight

# %%
# save_path = 'bloom-396m-zh'
# pruner = BloomVocabularyPruner()
# # 裁剪
# pruner.prune(MP1, MP2, save_path)
# # 检查裁剪的模型与原模型是否一致
# pruner.check(MP1, save_path, text='长风破浪会有时')

# %% [markdown]
# ### 3.donut模型
# - step1: 构建删减后的tokenizer.json

# %%
import langid
MP3 = "J:/model/mllm-model/donut-pretrain/20240102/pl-checkpoint-232000-ned-0.8460975410122905"

# %%
tokenizer3 = AutoTokenizer.from_pretrained(MP3)

# %%
tokenizer3.get_vocab()
# Out:
# {'て': 35872,
#  '▁appreciate': 51578,
#  '▁slow': 50091,
#  'kse': 9617,
#  '▁befinner': 11291,
#  '▁سۈرەت': 10351,
#  'vol': 38763,
#  '天堂': 54898,
#  'NAR': 54461,
#  'writer': 49237,
#  '一同': 47221,
#  '絹': 31154,
#  '▁amp': 41746,
#  '袖': 6643,
#  '▁fai': 16102,
#  '귀': 49708,
#  'さ': 47530,
#  'DB': 39373,
#  '▁MAX': 53631,
#  'dd': 39629,
#  '▁krásný': 20112,
#  '▁вираз': 18635,
#  '知って': 4541,
#  '▁gördük': 12530,
#  'liste': 7204,
#  'സിനെ': 15622,
#  '▁UU': 55440,
#  'head': 36294,
#  '▁Rigtig': 24053,
#  'jeva': 39096,
#  '▁Low': 46577,
#  '储': 52028,
#  '囝': 31440,
#  '▁mei': 44125,
#  '▁Mode': 38105,
#  'mish': 51645,
#  '▁நட': 3151,
#  '▁істеу': 4285,
#  'RS': 12790,
#  '▁акцыі': 15719,
#  '▁Astro': 53615,
#  '▁coach': 44204,
#  '▁Arra': 49014,
#  '▁слот': 5726,
#  '사업': 40664,
#  '11)': 42340,
#  '秧': 30912,
#  'வில': 12612,
#  '国务院': 43580,
#  '▁разве': 2432,
#  '▁콘텐츠': 51960,
#  '47)': 50535,
#  '霄': 24437,
#  '▁proběhl': 25881,
#  '▁Green': 12992,
#  'ées': 53519,
#  '▁tart': 12471,
#  '第': 41750,
#  '▁дисциплін': 10655,
#  '▁Lisa': 36882,
#  '지고': 42519,
#  'pedi': 46480,
#  '経': 40283,
#  'če': 34384,
#  '▁salīdzināt': 14966,
#  'uu': 16894,
#  '▁GENERAL': 23944,
#  '▁debut': 37477,
#  'jour': 58,
#  'rych': 37027,
#  'GO': 21935,
#  '▁main': 43635,
#  'frau': 54102,
#  '鷗': 30283,
#  '荚': 32470,
#  '▁exactly': 48077,
#  'imus': 53853,
#  'テキスト': 20878,
#  '▁daxilində': 21693,
#  '▁maintain': 51034,
#  '币': 55136,
#  '▁المناسب': 9050,
#  '▁қанша': 12125,
#  '攝影': 45864,
#  '▁సమస్యలు': 15115,
#  '▁маск': 11262,
#  'à': 7381,
#  'ਪਤੀ': 10895,
#  '▁Cuba': 39380,
#  '▁сонгуульд': 24363,
#  '▁correspond': 40440,
#  '”.': 51899,
#  'lege': 36889,
#  '▁Budget': 56337,
#  '▁MAN': 34333,
#  '▁floor': 50686,
#  '▁Ego': 48469,
#  'と言われる': 19631,
#  '▁SP': 5176,
#  '璽': 30376,
#  'rání': 3195,
#  '▁ಪ್ರಚಾರ': 13758,
#  '砚': 31513,
#  '▁2015.': 51844,
#  '經歷': 54298,
#  '▁거': 3742,
#  '▁tempos': 46847,
#  '模型': 49611,
#  '▁јавних': 21165,
#  '彣': 32832,
#  '▁diyeta': 1466,
#  'print': 37963,
#  '肄': 33131,
#  '▁яриа': 1137,
#  '▁party': 20358,
#  '皎': 31636,
#  '▁ಎನ್ನುವ': 4249,
#  '羨': 25518,
#  '▁dat': 46385,
#  '▁odškodn': 27182,
#  'rne': 50067,
#  'ér': 42170,
#  'hoff': 6233,
#  '써': 14983,
#  'vahendite': 19471,
#  'ugu': 28467,
#  '▁lake': 53650,
#  '▁propagand': 54901,
#  '▁tribu': 46220,
#  'فوض': 15374,
#  '▁موٹر': 16600,
#  'bok': 6794,
#  'rog': 35543,
#  '⇞': 31421,
#  '▁especiais': 2711,
#  'ാഴ്ച': 7211,
#  '辍': 30566,
#  '▁Vam': 40409,
#  '▁제주': 48273,
#  'ασμός': 12408,
#  '▁taste': 55002,
#  'વાસ': 838,
#  '鎂': 29857,
#  '▁Somalia': 48167,
#  '贻': 31582,
#  '合理': 39239,
#  '▁coma': 39985,
#  '▁цяло': 8898,
#  'იძემ': 21092,
#  '中古車': 22536,
#  '▁suspek': 11410,
#  '▁görülme': 23577,
#  '▁həvəs': 26821,
#  '▁1-': 40662,
#  '有限': 41819,
#  '坪': 51809,
#  'hơ': 1091,
#  '▁medieval': 55539,
#  '团结': 56453,
#  '亍': 57834,
#  '実家': 23305,
#  '▁23,': 31329,
#  'טת': 10883,
#  'orra': 43071,
#  'Ana': 50164,
#  '▁master': 36330,
#  '▁Mass': 50505,
#  '▁minus': 34600,
#  '▁come': 9278,
#  '翌': 58301,
#  '▁hope': 13402,
#  'štěstí': 57519,
#  '▁Lux': 53693,
#  'ցուցակ': 17713,
#  '▁корисник': 752,
#  '성을': 39208,
#  '▁თემაზე': 13833,
#  '因为它': 20123,
#  '眶': 29508,
#  '▁Fab': 40041,
#  '▁vejen': 788,
#  'ടും': 12750,
#  '릅': 30747,
#  '態': 45962,
#  '孑': 31309,
#  'Обществен': 20900,
#  '▁fëmijëve': 12511,
#  '殻': 30233,
#  '▁hake': 47628,
#  'lín': 18753,
#  '⇡': 31652,
#  '受到': 13851,
#  '▁სახის': 9391,
#  '▁sel': 54173,
#  '▁العاب': 7044,
#  'lami': 48652,
#  'lt': 6891,
#  '▁Cluj': 41226,
#  'kati': 39224,
#  '▁ବିରୋଧରେ': 9379,
#  '最も': 53573,
#  'bo': 53186,
#  '▁Axborot': 15474,
#  'inos': 40035,
#  '▁طراح': 12017,
#  '▁diàleg': 24769,
#  'hib': 34240,
#  '104': 48332,
#  '▁An': 54689,
#  'tais': 1235,
#  '▁combina': 26003,
#  '▁Yoga': 44685,
#  '々の': 56435,
#  'thur': 6657,
#  '▁පිටපත්': 26561,
#  '▁Kyl': 55172,
#  'sten': 34153,
#  '▁କଣ': 9334,
#  '吨': 58120,
#  '▁Till': 23612,
#  'inden': 25044,
#  '瑛': 30003,
#  '湮': 31184,
#  'uð': 7771,
#  '▁900': 18925,
#  '査': 22445,
#  'พิพิธภัณฑ์': 18972,
#  'enge': 37747,
#  'ragan': 2977,
#  '対策': 43848,
#  '▁Məcəllə': 16057,
#  '炣': 58867,
#  'RIC': 2789,
#  '↕': 30044,
#  '▁jartzea': 24495,
#  '▁Chy': 57112,
#  '▁individual': 4187,
#  'ącego': 14497,
#  '電子': 23200,
#  'ėlio': 11804,
#  '掌控': 23601,
#  'linger': 51796,
#  '▁21:00': 53511,
#  'meye': 24909,
#  'ENS': 40477,
#  'THAN': 16924,
#  '▁zen': 42156,
#  '▁Jonas': 48130,
#  '▁Euskara': 5762,
#  '奨': 20880,
#  '▁sim': 2008,
#  '因此': 44108,
#  '走廊': 23245,
#  '▁Omega': 53969,
#  'stokk': 23075,
#  '▁Nasi': 53296,
#  '▁క్రీ': 8678,
#  '▁síma': 4920,
#  '▁nevedel': 17639,
#  '丹': 34693,
#  'ក្រោម': 12900,
#  'ଜ୍ଞାନ': 20554,
#  '▁hub': 34491,
#  'ipa': 43995,
#  '▁support': 52350,
#  'vella': 53342,
#  '困': 39101,
#  '▁ಕುಳಿತು': 27190,
#  '襁': 33262,
#  '▁napisz': 22917,
#  '▁رساند': 57440,
#  '▁analys': 46465,
#  '第五': 48264,
#  '▁Viol': 54830,
#  '哑': 28868,
#  '▁Rou': 45108,
#  'able': 35372,
#  '▁Das': 19348,
#  '▁aka': 13281,
#  '▁Institut': 22162,
#  'มิติ': 19805,
#  '▁giudice': 23325,
#  '▁1,8': 45034,
#  'になると': 52591,
#  'entrepreneur': 57153,
#  '▁Bomb': 52896,
#  '원이': 1450,
#  'App': 39287,
#  '留': 4068,
#  '▁Бој': 23372,
#  '消費者': 39274,
#  '랙': 29440,
#  '▁maca': 48894,
#  '▁Kak': 39718,
#  '矞': 58720,
#  '▁rela': 12845,
#  'wch': 55818,
#  '微': 2329,
#  '▁gras': 34908,
#  '顔': 41200,
#  '撞': 42305,
#  '▁postal': 48573,
#  '▁Кари': 12359,
#  'ICI': 43832,
#  '重要的': 36893,
#  '▁مارك': 6444,
#  'とお': 11620,
#  '▁својом': 16239,
#  'Норматив': 16919,
#  '▁სს': 18384,
#  'VALI': 21863,
#  '琵': 29719,
#  'order': 52351,
#  '过了': 52384,
#  '設備': 22438,
#  '▁Chan': 35995,
#  '保': 46459,
#  '行的': 54669,
#  'int': 40572,
#  'teadus': 2992,
#  '▁cart': 40166,
#  '▁crea': 24655,
#  'report': 52087,
#  '啐': 32549,
#  '엌': 29903,
#  'itos': 34013,
#  '▁കോട്ടയം': 18510,
#  'sept': 39980,
#  'maid': 42381,
#  '▁Gay': 37110,
#  'ärer': 8641,
#  'ramai': 46620,
#  'ರಾಜ್ಯ': 19882,
#  '忽略': 4228,
#  '▁החברים': 26563,
#  '▁միջավայր': 12640,
#  '▁Ili': 35949,
#  '軾': 33383,
#  'litz': 54686,
#  '穹': 29886,
#  '▁luna': 34272,
#  '▁Angehörige': 25526,
#  '▁AK': 12653,
#  'zep': 51108,
#  '慤': 33018,
#  '凛': 58091,
#  'രചന': 13800,
#  '▁133': 47529,
#  '▁bestilt': 12961,
#  '▁Pleno': 17375,
#  '桔': 29728,
#  '▁Welcome': 55264,
#  '▁పదవి': 20905,
#  '쌤': 30009,
#  'ለሰ': 10627,
#  '苓': 30102,
#  '▁vestimenta': 19681,
#  'ti': 4306,
#  'そう': 13966,
#  'erland': 44030,
#  'Ổ': 57517,
#  '▁Inte': 35873,
#  'bling': 51957,
#  '▁@': 9142,
#  'アップデート': 25189,
#  '挂牌': 26675,
#  'muni': 51612,
#  '▁Western': 48000,
#  '躁': 13409,
#  '旸': 32594,
#  '鸩': 32967,
#  'maran': 49489,
#  '外交': 51135,
#  'ธร': 13399,
#  'フォーム': 6290,
#  '⇦': 31005,
#  'worm': 10319,
#  '▁pareiškė': 18595,
#  '▁Lập': 20026,
#  '<mask>': 57521,
#  '▁fris': 44742,
#  'netto': 14900,
#  '▁sta': 20631,
#  'qey': 11044,
#  'mengde': 20606,
#  '總是': 46533,
#  '▁Amal': 49610,
#  '▁хоць': 2610,
#  '据说': 21484,
#  '▁Loka': 1376,
#  '0.7': 8586,
#  '▁arte': 614,
#  '▁Obrigada': 19384,
#  '炳': 28276,
#  '▁Lond': 48221,
#  '▁చూపించ': 4679,
#  'पुत्र': 16948,
#  '想着': 11863,
#  '▁fri': 43392,
#  '•': 17725,
#  '°': 49945,
#  '▁Мали': 5627,
#  '甭': 31258,
#  'š': 51959,
#  '▁vəkili': 13226,
#  '▁officina': 26578,
#  '墓': 55220,
#  '▁concede': 55769,
#  '▁паказ': 1567,
#  '▁uboj': 14411,
#  'ý': 15650,
#  'franc': 56226,
#  '▁moi': 41021,
#  'हरे': 9775,
#  '医院': 11743,
#  'zingen': 10479,
#  'лазе': 13956,
#  '▁diesel': 47936,
#  'gp': 51840,
#  'తోపాటు': 20686,
#  '▁blanc': 39204,
#  '▁zo': 14121,
#  'girl': 42090,
#  'yy': 37363,
#  'onga': 49815,
#  '恭': 21898,
#  '\uf64f': 32060,
#  '▁SRI': 50595,
#  'eka': 34306,
#  'สอด': 21779,
#  '▁Fotó': 17399,
#  '▁industrial': 33966,
#  'ige': 36247,
#  '換': 20584,
#  'годно': 16958,
#  '▁katedral': 16808,
#  'ျပစ္': 21768,
#  'Тре': 21801,
#  '诿': 31066,
#  '▁Safari': 54254,
#  '私人': 50872,
#  'əcə': 3787,
#  '▁Bil': 1939,
#  '▁eraldi': 10823,
#  'bool': 10292,
#  'ギャ': 26245,
#  'wiązk': 8681,
#  '笛': 26930,
#  '伟大的': 17184,
#  '▁praktiske': 13112,
#  '希臘': 25464,
#  '▁pagas': 57106,
#  '▁Erd': 51070,
#  '▁hirmu': 17527,
#  '▁前': 52393,
#  'zimi': 44390,
#  '▁dieta': 34214,
#  '▁hamarosan': 17851,
#  '湃': 32311,
#  '▁1863': 10132,
#  '▁novo': 44487,
#  '▁ይታ': 14687,
#  '匾': 30506,
#  '▁Corre': 41753,
#  '鬍': 29716,
#  'lose': 46018,
#  '▁(15)': 36420,
#  '✻': 58790,
#  '▁ortamı': 18059,
#  '塔': 18731,
#  'נל': 237,
#  '喃': 29120,
#  '\ue173': 32504,
#  '▁baseado': 13019,
#  '▁Romani': 55210,
#  'rul': 8598,
#  '▁eelmise': 8360,
#  '▁billetter': 15144,
#  'mog': 34119,
#  '▁NBA': 44651,
#  'iau': 52598,
#  '有限责任公司': 26977,
#  'rang': 44382,
#  'भक्त': 11210,
#  'beszéd': 57438,
#  'たい': 4207,
#  '鐮': 31461,
#  'ROC': 21151,
#  '▁Nobel': 37597,
#  '▁φάση': 10264,
#  '▁rif': 48148,
#  '▁հաշվե': 25168,
#  '▁ڀيرو': 21374,
#  '▁Anthony': 56173,
#  'rija': 39721,
#  '▁folosește': 11815,
#  '▁prosim': 12931,
#  'браў': 17827,
#  '購買': 34592,
#  '▁បក្ស': 6959,
#  'август': 12714,
#  'kin': 54202,
#  '▁Ivana': 1017,
#  '▁köv': 21049,
#  '春': 6491,
#  'Kr': 50303,
#  '▁reflexion': 20150,
#  '变化': 34968,
#  '▁abusi': 14676,
#  '▁2016.': 47280,
#  'ration': 36015,
#  '相當': 35164,
#  '▁maintsy': 21307,
#  'fie': 45357,
#  'λαδ': 19895,
#  '▁bổng': 17955,
#  'tako': 54389,
#  'utta': 19095,
#  '▁zoo': 49622,
#  '▁machine': 38199,
#  '▁312': 11204,
#  '创办': 21980,
#  '▁Urban': 37526,
#  '▁kin': 35758,
#  'galerie': 18172,
#  '▁sy': 56302,
#  '▁perumahan': 26067,
#  'Ce': 42732,
#  '▁ulterior': 51337,
#  '▁Qo': 19115,
#  '▁надзвичайн': 20455,
#  '▁wensen': 57350,
#  'gai': 23330,
#  '怄': 32804,
#  '▁Phân': 15106,
#  'qin': 39533,
#  '서울': 49579,
#  'labor': 34941,
#  '其中': 48114,
#  '▁வேற': 18500,
#  '▁광고': 44003,
#  'らせる': 27365,
#  'osa': 40404,
#  '▁Veli': 50319,
#  '党': 7643,
#  'բաղ': 22543,
#  'セ': 34303,
#  '▁equi': 46424,
#  '▁objavlja': 24147,
#  'ьян': 891,
#  '▁Brez': 50270,
#  '▁Срок': 16237,
#  'bita': 37859,
#  '▁2004': 42379,
#  'gri': 5548,
#  'īsim': 19677,
#  '▁argentino': 14957,
#  '▁lub': 36206,
#  'kg': 53578,
#  '彐': 58606,
#  '前往': 35291,
#  '▁منتدى': 4362,
#  'verktyg': 27371,
#  '語': 55140,
#  '▁vinduer': 19244,
#  'SU': 14935,
#  '▁av': 19025,
#  '카톡': 50572,
#  'ROM': 46704,
#  'タブレット': 25978,
#  '▁Reply': 5756,
#  'ኦሮሞ': 2402,
#  '礦': 50371,
#  '▁FB': 38365,
#  '▁..': 11224,
#  '┤': 30855,
#  'mona': 54101,
#  '▁ready': 40780,
#  '▁blot': 41402,
#  'atum': 51395,
#  'sindən': 2479,
#  'ுவதாக': 14089,
#  '▁Oktober': 18519,
#  '▁gym': 35675,
#  '쏭': 31175,
#  '▁Negara': 23321,
#  '드는': 122,
#  '估計': 22450,
#  'â': 45498,
#  '▁Arian': 5190,
#  '▁төгс': 13390,
#  '▁iznad': 7652,
#  'XX': 40587,
#  '中学': 54327,
#  'pasok': 243,
#  '▁있을': 35674,
#  '▁предварительно': 21556,
#  'nti': 38086,
#  'master': 42098,
#  'ლოგი': 1666,
#  '▁1935': 46690,
#  'epoca': 550,
#  '▁egészen': 804,
#  '🍎': 32375,
#  '▁kelti': 6090,
#  'tu': 41532,
#  '▁férfiak': 11213,
#  'wie': 47234,
#  '▁(7)': 54077,
#  '▁අහන්න': 10282,
#  'أفادت': 27926,
#  '探し': 6300,
#  '350': 41346,
#  '▁far': 23126,
#  'gger': 24516,
#  'ducere': 8302,
#  'ssa': 4816,
#  '▁Spol': 19885,
#  '▁ayrılmış': 28494,
#  '▁Mail': 34192,
#  '啤': 58274,
#  'ؔ': 24224,
#  '▁Paris': 50052,
#  '推廣': 51302,
#  'nty': 46707,
#  '▁gjet': 580,
#  'ందంటే': 27032,
#  '▁ကား': 4820,
#  '▁RAM': 34603,
#  '做了': 39600,
#  '▁команди': 831,
#  'プ': 16157,
#  '▁შიში': 24338,
#  'kového': 4965,
#  'соответствующего': 24595,
#  '▁R': 46982,
#  '▁KAL': 51555,
#  '▁Job': 36844,
#  '▁همکاران': 18166,
#  'เหมือนเดิม': 26149,
#  '的战略': 14342,
#  '▁episode': 43018,
#  '▁consulter': 7104,
#  '▁mamlakatimiz': 20593,
#  '▁Mart': 7933,
#  '▁straf': 53622,
#  '▁Felix': 5971,
#  'venir': 50387,
#  'äisiä': 14555,
#  '的方式': 21298,
#  '葩': 29391,
#  '▁χωρών': 21840,
#  'SAL': 443,
#  '▁серии': 11839,
#  '殖': 57906,
#  'upe': 42999,
#  'ТЬ': 57483,
#  'zet': 51284,
#  '▁දිවි': 10053,
#  '▁Градск': 5076,
#  '▁López': 50600,
#  '▁분': 21365,
#  'LD': 36094,
#  '星座': 17746,
#  '耦': 33580,
#  '不敢': 41860,
#  '▁Yvonne': 28566,
#  '▁bez': 5264,
#  'ልም': 1278,
#  '▁występuje': 20227,
#  '▁tələbələr': 358,
#  '쳐': 45222,
#  '酡': 58736,
#  '皆さん': 50710,
#  'lane': 36759,
#  'cal': 48708,
#  '쏜': 31376,
#  'पाठ': 16974,
#  '▁110': 5213,
#  '▁אליו': 1706,
#  '▁ուղարկ': 13925,
#  '▁Mind': 35654,
#  '▁guess': 45450,
#  '▁Pievienot': 5881,
#  '▁novidades': 5575,
#  'сныг': 17596,
#  '▁বাংলাদেশি': 13401,
#  '▁lugemis': 13861,
#  'hatod': 17943,
#  'acte': 45854,
#  '▁tee': 36854,
#  '𥚃': 32529,
#  '▁observer': 14114,
#  '創作': 40191,
#  '▁configura': 44966,
#  'ास्पद': 26237,
#  '括': 7162,
#  'ratu': 35958,
#  '▁Треб': 6216,
#  '▁Dijital': 26946,
#  'alli': 47983,
#  '>': 34791,
#  '▁Kil': 39143,
#  '▁yavaş': 1254,
#  'uar': 26111,
#  '▁xatırla': 13187,
#  '▁tähenda': 23160,
#  '對方': 46917,
#  '▁1/2': 25718,
#  '▁Bunga': 48194,
#  '仃': 31775,
#  '▁natuurlik': 6068,
#  '讥': 31449,
#  '济南': 12977,
#  '▁vagina': 47522,
#  'ERING': 6913,
#  '▁Hard': 39347,
#  'public': 45522,
#  '愧': 58009,
#  '▁realiz': 11544,
#  '▁biološk': 26958,
#  '▁shall': 37829,
#  'BP': 45157,
#  '▁كۆرۈپ': 26083,
#  'นครสวรรค์': 27108,
#  '▁pracował': 24938,
#  '▁окутуу': 20802,
#  'енной': 1320,
#  '▁Nagy': 26488,
#  '荫': 30548,
#  '▁funcionalidad': 16374,
#  '▁호텔': 7673,
#  '▁ku': 26602,
#  '▁goboleedyada': 26541,
#  'お': 34356,
#  'vod': 1194,
#  'жную': 5170,
#  '▁Zimmer': 40515,
#  '諄': 33122,
#  '▁سلسلة': 12375,
#  '各方面': 9747,
#  '뚝': 28881,
#  '》(': 37310,
#  '▁to': 41641,
#  '衣': 4890,
#  'bur': 46167,
#  'sunt': 2280,
#  '▁Asi': 38811,
#  '▁Universal': 44214,
#  '▁fie': 44943,
#  '漾': 57999,
#  '▁художн': 13242,
#  'ela': 38083,
#  '▁Chuck': 15049,
#  '▁Житомир': 19365,
#  '联合国': 1502,
#  '▁በራሱ': 19843,
#  'loos': 37616,
#  '▁1904': 56714,
#  '▁vita': 42896,
#  '▁cutie': 13665,
#  '▁primary': 13868,
#  '▁Gun': 34114,
#  '▁Luci': 43363,
#  '▁remek': 7301,
#  '骗': 48346,
#  '▁banda': 644,
#  '▁Oscar': 37198,
#  '在北京': 49991,
#  '晔': 58055,
#  '▁geometri': 53325,
#  'liter': 39475,
#  'menneske': 24144,
#  'aeque': 21637,
#  '덫': 33281,
#  '▁അത്തര': 15359,
#  '60,000': 21718,
#  '▁alba': 41472,
#  '180': 39360,
#  '々': 29975,
#  'IB': 35769,
#  '經濟': 14848,
#  'kaasu': 19133,
#  '▁anlattı': 16660,
#  '▁Kö': 24892,
#  '▁Island': 19183,
#  '繽': 32945,
#  '高的': 43858,
#  '▁요소': 9883,
#  '▁pe': 34997,
#  '깜': 29270,
#  '▁Jones': 35545,
#  'stro': 48156,
#  '▁porte': 27715,
#  '▁1971': 36647,
#  '负': 38538,
#  'hatra': 50465,
#  '▁катар': 176,
#  '多次': 41482,
#  '▁Enter': 46462,
#  'situation': 6897,
#  'top': 9264,
#  '▁optimal': 28538,
#  '▁nudi': 39382,
#  '▁Scr': 38915,
#  '득': 48029,
#  '▁metro': 27347,
#  'oid': 42632,
#  '555': 54182,
#  'በራ': 2399,
#  '▁գործերի': 12233,
#  '▁bomb': 44350,
#  'REM': 53246,
#  '▁slo': 33930,
#  '饶': 28416,
#  '규': 37014,
#  '地下': 47689,
#  'อัพ': 734,
#  '▁sound': 41542,
#  '▁wygodny': 28222,
#  'ezi': 2015,
#  'гчдын': 16718,
#  '랬': 23609,
#  'fast': 39377,
#  '▁음악': 47067,
#  'utama': 50354,
#  '疎': 33728,
#  '▁deg': 34712,
#  'fuso': 20632,
#  'cci': 43794,
#  'ére': 52408,
#  'dís': 55089,
#  '▁lasciare': 11608,
#  '▁түсті': 11132,
#  'mp': 34510,
#  '▁Infatti': 17116,
#  'hatta': 5555,
#  'auteur': 46368,
#  '▁stia': 11658,
#  '▁এমপি': 21918,
#  '▁bildu': 57081,
#  'دوار': 12309,
#  '▁силна': 12358,
#  'ofa': 49604,
#  '瑷': 32834,
#  '▁Water': 34891,
#  'ປິດ': 8767,
#  '▁blisko': 113,
#  '崧': 32340,
#  '▁Lar': 42059,
#  '▁큰': 17420,
#  'impl': 4095,
#  '▁stede': 2883,
#  '匆': 30101,
#  'DAC': 20526,
#  '鎬': 31164,
#  '▁Κερ': 24550,
#  '懾': 30312,
#  '龊': 33308,
#  '▁Account': 46659,
#  '▁Stal': 54211,
#  'ために': 38609,
#  '겠습니다': 51240,
#  '▁Đ': 41042,
#  '▁ਬਦਲ': 2805,
#  '▁reģistrē': 22116,
#  'MAS': 39763,
#  '▁lec': 41076,
#  'コーヒー': 10068,
#  '▁британски': 9107,
#  '昰': 32681,
#  'ʿ': 29684,
#  '萨': 37158,
#  '▁Hakim': 54569,
#  '▁tak': 41808,
#  'のみ': 42552,
#  '▁Velike': 21181,
#  'беларуску': 8509,
#  '▁energetic': 43349,
#  '刈': 29788,
#  '뿍': 30561,
#  '本地': 48019,
#  '▁абарон': 3405,
#  'PO': 56730,
#  '▁Høj': 55686,
#  '▁mladost': 14196,
#  '▁بہن': 17134,
#  '▁árbore': 16211,
#  'ვნი': 9174,
#  '▁Konsum': 8034,
#  '▁erişim': 20591,
#  'lingar': 4167,
#  'どういう': 18034,
#  '▁घुम': 10598,
#  '组': 10182,
#  'ֆինանսավոր': 23850,
#  '▁الكرة': 10595,
#  'utan': 16981,
#  '莪': 31422,
#  '▁nos': 56221,
#  'ရောင်': 8255,
#  '▁Cooperativa': 26121,
#  '闯': 57849,
#  '我和': 52790,
#  'soo': 35946,
#  'դին': 11628,
#  '▁בשעה': 5849,
#  '▁radu': 41031,
#  '面對': 40871,
#  '▁мањи': 9015,
#  '▁selatan': 17735,
#  'heng': 36872,
#  '十一': 53352,
#  '缄': 31462,
#  'KEY': 19431,
#  '保險': 49877,
#  '▁meg': 49828,
#  '惚': 29160,
#  'zam': 9272,
#  '🇵': 30804,
#  'aan': 34850,
#  '▁ff': 34403,
#  '▁jedinica': 23878,
#  '有些': 4278,
#  '▁corri': 36726,
#  '▁کلاه': 20931,
#  '▁Alfred': 50635,
#  'Хамгийн': 6269,
#  '▁Трен': 10301,
#  '725': 20033,
#  '▁display': 40996,
#  '▁September': 46481,
#  'oittamaan': 26215,
#  '▁edycji': 21997,
#  '泌': 58012,
#  '▁κυβερνητικ': 12660,
#  '▁rever': 39392,
#  '▁hochwertige': 11353,
#  '✤': 30948,
#  '▁Bez': 14014,
#  'ѕ': 14288,
#  'hua': 39418,
#  '▁godkendt': 12989,
#  'éag': 6249,
#  '▁menstrua': 49535,
#  '▁방문': 40788,
#  '▁Abbas': 42698,
#  '▁ਚੁੱਕ': 2193,
#  'rni': 7769,
#  '▁cijenu': 17332,
#  '▁показват': 12893,
#  '▁ses': 37352,
#  '信心': 44994,
#  'rado': 14552,
#  '宝宝': 48008,
#  '▁bran': 36912,
#  '▁Qirg': 15575,
#  '▁Monsieur': 19382,
#  '은': 49107,
#  'kymmentä': 22359,
#  '阻碍': 26922,
#  'ád': 10099,
#  '▁ball': 15046,
#  '▁Castell': 36994,
#  'mium': 2678,
#  '術': 41657,
#  '▁empat': 28479,
#  '▁Browser': 54086,
#  'fag': 47209,
#  '▁dream': 42619,
#  '▁پیچ': 7757,
#  '卜': 11634,
#  '▁hel': 51989,
#  '▁Cro': 31855,
#  '▁ప్రయత్నం': 13524,
#  '很': 24918,
#  '▁провеждане': 10618,
#  '拒絕': 55843,
#  '╄': 31848,
#  '距離': 37004,
#  '纬': 29086,
#  '▁байвал': 4331,
#  '▁singular': 48577,
#  'すこと': 6232,
#  '▁autónoma': 18417,
#  '▁ڈے': 22102,
#  'sari': 36885,
#  '煮': 42844,
#  '▁kn': 16348,
#  '俑': 30574,
#  'sp': 49247,
#  '▁السلوك': 26008,
#  'dva': 48874,
#  '龈': 33253,
#  '▁cab': 39205,
#  '▁rolę': 11319,
#  '▁forces': 53436,
#  '灾难': 25039,
#  '▁labā': 12483,
#  '権': 38107,
#  ...}

# %%
## 统计词表中的语言分布
lang_dist, lang_dist_list = {}, {}
for idx, voc in enumerate(tqdm(tokenizer3.get_vocab())):
    r = langid.classify(voc)[0]
    if r not in lang_dist:
        lang_dist_list[r] = [0, []]
        lang_dist[r] = 0
    lang_dist_list[r][0] += 1
    lang_dist[r] += 1
    lang_dist_list[r][1].append(voc)
    if idx <= 10:
        print(voc, r)
# Out:
#   0%|          | 72/58891 [00:02<20:22, 48.13it/s]
# て ja
# ▁appreciate en
# ▁slow lv
# kse fi
# ▁befinner en
# ▁سۈرەت ug
# vol en
# 天堂 zh
# NAR en
# writer en
# 一同 zh
# 100%|██████████| 58891/58891 [01:29<00:00, 659.87it/s]

# %%
import json
lang_dist = dict(sorted(lang_dist.items(), key=lambda x:x[1], reverse=True))
lang_dist_list = dict(sorted(lang_dist_list.items(), key=lambda x:x[1], reverse=True))

lang_dist.keys(), lang_dist

with open("lang_dist.json", "w", encoding="utf-8") as f1, \
    open("lang_dist_list.json", "w", encoding="utf-8") as f2:
    f1.write(json.dumps(lang_dist, ensure_ascii=False, indent=2))
    f2.write(json.dumps(lang_dist_list, ensure_ascii=False, indent=2))

# %%
lang_dist["zh"]
# Out:
# 12734

# %%
"飞" in lang_dist_list["zh"][1]
# Out:
# True

# %%
# 重新保存tokenzier.json
tokenizer3_dict = tokenizer3.__dict__
tokenizer3_dict, type(tokenizer3_dict)
# Out:
# ({'_tokenizer': <tokenizers.Tokenizer at 0x1da82c3ebe0>,
#   '_decode_use_source_tokenizer': False,
#   'init_inputs': (),
#   'init_kwargs': {'bos_token': '<s>',
#    'eos_token': '</s>',
#    'sep_token': '</s>',
#    'cls_token': '<s>',
#    'unk_token': '<unk>',
#    'pad_token': '<pad>',
#    'mask_token': AddedToken("<mask>", rstrip=False, lstrip=True, single_word=False, normalized=True),
#    'added_tokens_decoder': {'0': {'content': '<s>',
#      'lstrip': False,
#      'normalized': False,
#      'rstrip': False,
#      'single_word': False,
#      'special': True},
#     '1': {'content': '<pad>',
#      'lstrip': False,
#      'normalized': False,
#      'rstrip': False,
#      'single_word': False,
#      'special': True},
#     '2': {'content': '</s>',
#      'lstrip': False,
#      'normalized': False,
#      'rstrip': False,
#      'single_word': False,
#      'special': True},
#     '3': {'content': '<unk>',
#      'lstrip': False,
#      'normalized': False,
#      'rstrip': False,
#      'single_word': False,
#      'special': True},
#     '57521': {'content': '<mask>',
#      'lstrip': True,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': True},
#     '57522': {'content': '<sep/>',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57523': {'content': '<s_iitcdip>',
#      'lstrip': False,
#      'normalized': False,
#      'rstrip': False,
#      'single_word': False,
#      'special': True},
#     '57524': {'content': '<s_synthdog>',
#      'lstrip': False,
#      'normalized': False,
#      'rstrip': False,
#      'single_word': False,
#      'special': True},
#     '57525': {'content': '</n>',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57526': {'content': '册',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57527': {'content': '1',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57528': {'content': '茄',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57529': {'content': '链',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57530': {'content': '枢',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57531': {'content': '摘',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57532': {'content': '绞',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57533': {'content': '驱',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57534': {'content': '循',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57535': {'content': '央',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57536': {'content': '鸣',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57537': {'content': '蜂',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57538': {'content': '堵',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57539': {'content': '针',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57540': {'content': '泵',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57541': {'content': '灾',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57542': {'content': '扑',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57543': {'content': '饼',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57544': {'content': '滇',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57545': {'content': '酥',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57546': {'content': '咸',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57547': {'content': '脉',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57548': {'content': '烘',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57549': {'content': '陷',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57550': {'content': '湘',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57551': {'content': '呵',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57552': {'content': '怡',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57553': {'content': '遮',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57554': {'content': '铝',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57555': {'content': '兽',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57556': {'content': '译',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57557': {'content': '润',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57558': {'content': '①',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57559': {'content': '●',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57560': {'content': '尘',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57561': {'content': '滤',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57562': {'content': '纹',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57563': {'content': '暂',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57564': {'content': '慎',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57565': {'content': '析',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57566': {'content': '颜',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57567': {'content': '验',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57568': {'content': '跃',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57569': {'content': '阶',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57570': {'content': '键',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57571': {'content': '≤',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57572': {'content': '胶',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57573': {'content': '橡',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57574': {'content': '阔',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57575': {'content': '舱',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57576': {'content': '览',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57577': {'content': '寸',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57578': {'content': '伏',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57579': {'content': '鼎',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57580': {'content': '螺',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57581': {'content': '扩',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57582': {'content': '芯',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57583': {'content': '址',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57584': {'content': '径',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57585': {'content': '络',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57586': {'content': '≥',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57587': {'content': '↑',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '57588': {'content': '悬',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '
',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58442': {'content': '碁',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58443': {'content': '旌',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58444': {'content': '芩',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58445': {'content': '芎',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58446': {'content': '蠕',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58447': {'content': '麝',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58448': {'content': '芍',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58449': {'content': '椽',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58450': {'content': '咂',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58451': {'content': '煽',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58452': {'content': '疖',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58453': {'content': '皲',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58454': {'content': '蹼',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58455': {'content': '≈',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58456': {'content': '腓',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58457': {'content': '痈',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58458': {'content': '痨',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58459': {'content': '浠',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58460': {'content': '耵',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58461': {'content': '阡',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58462': {'content': '拮',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58463': {'content': '阪',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58464': {'content': '啫',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58465': {'content': '胪',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58466': {'content': '桡',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58467': {'content': '喹',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58468': {'content': '湫',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58469': {'content': '颢',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58470': {'content': '鄄',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58471': {'content': '沔',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58472': {'content': '寕',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58473': {'content': '扌',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58474': {'content': '柞',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58475': {'content': '訓',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58476': {'content': '钇',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58477': {'content': '铋',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58478': {'content': '锶',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58479': {'content': '锆',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58480': {'content': '臆',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58481': {'content': '琮',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58482': {'content': '鹂',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58483': {'content': '烃',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58484': {'content': '鳃',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58485': {'content': '洄',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58486': {'content': '偌',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58487': {'content': '匕',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58488': {'content': '镧',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58489': {'content': '娌',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58490': {'content': '宦',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58491': {'content': '咻',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58492': {'content': '婺',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58493': {'content': '喏',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58494': {'content': '夔',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58495': {'content': '圻',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58496': {'content': '餠',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58497': {'content': '陉',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58498': {'content': '铈',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58499': {'content': '贲',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58500': {'content': '毙',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58501': {'content': '砜',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58502': {'content': '苎',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58503': {'content': '邝',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58504': {'content': '唢',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58505': {'content': '铪',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58506': {'content': '钽',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58507': {'content': '铍',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58508': {'content': '铱',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58509': {'content': '脲',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58510': {'content': '诘',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58511': {'content': '頔',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58512': {'content': '栎',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58513': {'content': '镭',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58514': {'content': '碩',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58515': {'content': '饸',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     '58516': {'content': '築',
#      'lstrip': False,
#      'normalized': True,
#      'rstrip': False,
#      'single_word': False,
#      'special': False},
#     ...},
#    'additional_special_tokens': ['<s_iitcdip>', '<s_synthdog>'],
#    'clean_up_tokenization_spaces': True,
#    'max_length': 2560,
#    'model_max_length': 1000000000000000019884624838656,
#    'pad_to_multiple_of': None,
#    'pad_token_type_id': 0,
#    'padding_side': 'right',
#    'processor_class': 'DonutProcessor',
#    'sp_model_kwargs': {},
#    'stride': 0,
#    'truncation_side': 'right',
#    'truncation_strategy': 'longest_first',
#    'special_tokens_map_file': 'J:/model/mllm-model/donut-pretrain/20240102/pl-checkpoint-232000-ned-0.8460975410122905\\special_tokens_map.json',
#    'name_or_path': 'J:/model/mllm-model/donut-pretrain/20240102/pl-checkpoint-232000-ned-0.8460975410122905'},
#   'name_or_path': 'J:/model/mllm-model/donut-pretrain/20240102/pl-checkpoint-232000-ned-0.8460975410122905',
#   '_processor_class': 'DonutProcessor',
#   'model_max_length': 1000000000000000019884624838656,
#   'padding_side': 'right',
#   'truncation_side': 'right',
#   'model_input_names': ['input_ids', 'attention_mask'],
#   'clean_up_tokenization_spaces': True,
#   'deprecation_warnings': {},
#   '_in_target_context_manager': False,
#   '_bos_token': '<s>',
#   '_eos_token': '</s>',
#   '_unk_token': '<unk>',
#   '_sep_token': '</s>',
#   '_pad_token': '<pad>',
#   '_cls_token': '<s>',
#   '_mask_token': '<mask>',
#   '_pad_token_type_id': 0,
#   '_additional_special_tokens': ['<s_iitcdip>', '<s_synthdog>'],
#   'verbose': True,
#   'vocab_file': 'J:/model/mllm-model/donut-pretrain/20240102/pl-checkpoint-232000-ned-0.8460975410122905\\sentencepiece.bpe.model',
#   'can_save_slow_tokenizer': True},
#  dict)

# %%
tokenizer3
# Out:
# XLMRobertaTokenizerFast(name_or_path='J:/model/mllm-model/donut-pretrain/20240102/pl-checkpoint-232000-ned-0.8460975410122905', vocab_size=57522, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'sep_token': '</s>', 'pad_token': '<pad>', 'cls_token': '<s>', 'mask_token': '<mask>', 'additional_special_tokens': ['<s_iitcdip>', '<s_synthdog>']}, clean_up_tokenization_spaces=True)

# %%
tokenizer3_file = "J:/model/mllm-model/donut-pretrain/20240102/pl-checkpoint-232000-ned-0.8460975410122905/tokenizer.json"
tokenizer3_config_file = "J:/model/mllm-model/donut-pretrain/20240102/pl-checkpoint-232000-ned-0.8460975410122905/tokenizer_config.json"

with open(tokenizer3_file, "r", encoding="utf-8") as f1,\
        open(tokenizer3_config_file, "r", encoding="utf-8") as f2:
    tokenizer_data = json.load(f1)
    tokenizer3_config_data = json.load(f2)

# %%
tokenizer_data
# Out:
# {'version': '1.0',
#  'truncation': {'direction': 'Right',
#   'max_length': 2560,
#   'strategy': 'LongestFirst',
#   'stride': 0},
#  'padding': {'strategy': {'Fixed': 2560},
#   'direction': 'Right',
#   'pad_to_multiple_of': None,
#   'pad_id': 1,
#   'pad_type_id': 0,
#   'pad_token': '<pad>'},
#  'added_tokens': [{'id': 0,
#    'content': '<s>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': False,
#    'special': True},
#   {'id': 1,
#    'content': '<pad>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': False,
#    'special': True},
#   {'id': 2,
#    'content': '</s>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': False,
#    'special': True},
#   {'id': 3,
#    'content': '<unk>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': False,
#    'special': True},
#   {'id': 57521,
#    'content': '<mask>',
#    'single_word': False,
#    'lstrip': True,
#    'rstrip': False,
#    'normalized': True,
#    'special': True},
#   {'id': 57522,
#    'content': '<sep/>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57523,
#    'content': '<s_iitcdip>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': False,
#    'special': True},
#   {'id': 57524,
#    'content': '<s_synthdog>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': False,
#    'special': True},
#   {'id': 57525,
#    'content': '</n>',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57526,
#    'content': '册',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57527,
#    'content': '1',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57528,
#    'content': '茄',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57529,
#    'content': '链',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57530,
#    'content': '枢',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57531,
#    'content': '摘',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57532,
#    'content': '绞',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57533,
#    'content': '驱',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57534,
#    'content': '循',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57535,
#    'content': '央',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57536,
#    'content': '鸣',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57537,
#    'content': '蜂',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57538,
#    'content': '堵',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57539,
#    'content': '针',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57540,
#    'content': '泵',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57541,
#    'content': '灾',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57542,
#    'content': '扑',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57543,
#    'content': '饼',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57544,
#    'content': '滇',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57545,
#    'content': '酥',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57546,
#    'content': '咸',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57547,
#    'content': '脉',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57548,
#    'content': '烘',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57549,
#    'content': '陷',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57550,
#    'content': '湘',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57551,
#    'content': '呵',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57552,
#    'content': '怡',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57553,
#    'content': '遮',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57554,
#    'content': '铝',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57555,
#    'content': '兽',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57556,
#    'content': '译',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57557,
#    'content': '润',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57558,
#    'content': '①',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57559,
#    'content': '●',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57560,
#    'content': '尘',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57561,
#    'content': '滤',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57562,
#    'content': '纹',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57563,
#    'content': '暂',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57564,
#    'content': '慎',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57565,
#    'content': '析',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57566,
#    'content': '颜',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57567,
#    'content': '验',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57568,
#    'content': '跃',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57569,
#    'content': '阶',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57570,
#    'content': '键',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57571,
#    'content': '≤',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57572,
#    'content': '胶',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57573,
#    'content': '橡',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57574,
#    'content': '阔',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57575,
#    'content': '舱',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57576,
#    'content': '览',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57577,
#    'content': '寸',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57578,
#    'content': '伏',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57579,
#    'content': '鼎',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57580,
#    'content': '螺',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57581,
#    'content': '扩',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57582,
#    'content': '芯',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57583,
#    'content': '址',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57584,
#    'content': '径',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57585,
#    'content': '络',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57586,
#    'content': '≥',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57587,
#    'content': '↑',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57588,
#    'content': '悬',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57589,
#    'content': '唑',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57590,
#    'content': '筛',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57591,
#    'content': '蝴',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57592,
#    'content': '蝶',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57593,
#    'content': '輸',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57594,
#    'content': '贯',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57595,
#    'content': '卸',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57596,
#    'content': '夹',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57597,
#    'content': '盲',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57598,
#    'content': '毫',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57599,
#    'content': '挽',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57600,
#    'content': '躺',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57601,
#    'content': '训',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57602,
#    'content': '辉',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57603,
#    'content': '枕',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57604,
#    'content': '励',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57605,
#    'content': '偿',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57606,
#    'content': '拨',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57607,
#    'content': '曝',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57608,
#    'content': '阅',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57609,
#    'content': '悦',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57610,
#    'content': '竭',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57611,
#    'content': '涵',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57612,
#    'content': '烦',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57613,
#    'content': '攀',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57614,
#    'content': '■',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57615,
#    'content': '惯',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57616,
#    'content': '椅',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57617,
#    'content': '勿',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57618,
#    'content': '醋',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57619,
#    'content': '烯',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57620,
#    'content': '邻',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57621,
#    'content': '酯',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57622,
#    'content': '腔',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57623,
#    'content': '粘',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57624,
#    'content': '偶',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57625,
#    'content': '哺',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57626,
#    'content': '呈',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57627,
#    'content': '柄',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57628,
#    'content': '锂',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57629,
#    'content': '涌',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57630,
#    'content': '缠',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57631,
#    'content': '绕',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57632,
#    'content': '臂',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57633,
#    'content': '贤',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57634,
#    'content': '够',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57635,
#    'content': '罩',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57636,
#    'content': '弓',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57637,
#    'content': '蚀',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57638,
#    'content': '泄',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57639,
#    'content': '卓',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57640,
#    'content': '释',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57641,
#    'content': '馨',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57642,
#    'content': '锐',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57643,
#    'content': '脏',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57644,
#    'content': '扯',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57645,
#    'content': '擅',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57646,
#    'content': '袭',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57647,
#    'content': '确',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57648,
#    'content': '况',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57649,
#    'content': '岐',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57650,
#    'content': '遥',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57651,
#    'content': '择',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57652,
#    'content': '爪',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57653,
#    'content': '闲',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57654,
#    'content': '鑫',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57655,
#    'content': '罚',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57656,
#    'content': '膏',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57657,
#    'content': '疾',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57658,
#    'content': '筑',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57659,
#    'content': '悉',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57660,
#    'content': '颈',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57661,
#    'content': '烂',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57662,
#    'content': '赔',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57663,
#    'content': '萍',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57664,
#    'content': '糕',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57665,
#    'content': '睛',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57666,
#    'content': '绘',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57667,
#    'content': '喷',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57668,
#    'content': '艳',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57669,
#    'content': '厦',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57670,
#    'content': '恕',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57671,
#    'content': '担',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57672,
#    'content': '熬',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57673,
#    'content': '辐',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57674,
#    'content': '肾',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57675,
#    'content': '萝',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57676,
#    'content': '咳',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57677,
#    'content': '贫',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57678,
#    'content': '冻',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57679,
#    'content': '帧',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57680,
#    'content': '歧',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57681,
#    'content': '豹',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57682,
#    'content': '淮',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57683,
#    'content': '垒',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57684,
#    'content': '踝',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57685,
#    'content': '砖',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57686,
#    'content': '凑',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57687,
#    'content': '旨',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57688,
#    'content': '澜',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57689,
#    'content': '灌',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57690,
#    'content': '拌',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57691,
#    'content': '矩',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57692,
#    'content': '奎',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57693,
#    'content': '狐',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57694,
#    'content': '靶',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57695,
#    'content': '※',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57696,
#    'content': '际',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57697,
#    'content': '肤',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57698,
#    'content': '酵',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57699,
#    'content': '疗',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57700,
#    'content': '菱',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57701,
#    'content': '厢',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57702,
#    'content': '硅',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57703,
#    'content': '垂',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57704,
#    'content': '罐',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57705,
#    'content': '铭',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57706,
#    'content': '淋',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57707,
#    'content': '竞',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57708,
#    'content': '矫',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57709,
#    'content': '锅',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57710,
#    'content': '饱',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57711,
#    'content': '浅',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57712,
#    'content': '雾',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57713,
#    'content': '匠',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57714,
#    'content': '兔',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57715,
#    'content': '兑',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57716,
#    'content': '颗',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57717,
#    'content': '旦',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57718,
#    'content': '亏',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57719,
#    'content': '氯',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57720,
#    'content': '煌',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57721,
#    'content': '恢',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57722,
#    'content': '履',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57723,
#    'content': '殊',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57724,
#    'content': '递',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57725,
#    'content': '弦',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57726,
#    'content': '斤',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57727,
#    'content': '披',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57728,
#    'content': '债',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57729,
#    'content': '挤',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57730,
#    'content': '卉',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57731,
#    'content': '棚',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57732,
#    'content': '唯',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57733,
#    'content': '挥',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57734,
#    'content': '培',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57735,
#    'content': '贷',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57736,
#    'content': '曰',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57737,
#    'content': '霜',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57738,
#    'content': '纤',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57739,
#    'content': '谊',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57740,
#    'content': '缔',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57741,
#    'content': '铜',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57742,
#    'content': '询',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57743,
#    'content': '栋',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57744,
#    'content': '艰',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57745,
#    'content': '徽',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57746,
#    'content': '劣',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57747,
#    'content': '泛',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57748,
#    'content': '奢',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57749,
#    'content': '喀',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57750,
#    'content': '□',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57751,
#    'content': '辨',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57752,
#    'content': '刮',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57753,
#    'content': '帖',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57754,
#    'content': '谣',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57755,
#    'content': '熹',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57756,
#    'content': '纵',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57757,
#    'content': '抚',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57758,
#    'content': '皱',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57759,
#    'content': '迅',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57760,
#    'content': '脾',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57761,
#    'content': '傅',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57762,
#    'content': '姬',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57763,
#    'content': '橘',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57764,
#    'content': '滚',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57765,
#    'content': '鲍',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57766,
#    'content': '埠',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57767,
#    'content': '忧',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57768,
#    'content': '酌',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57769,
#    'content': '拟',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57770,
#    'content': '济',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57771,
#    'content': '肇',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57772,
#    'content': '腺',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57773,
#    'content': '皂',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57774,
#    'content': '伐',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57775,
#    'content': '仰',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57776,
#    'content': '牵',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57777,
#    'content': '挡',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57778,
#    'content': '昏',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57779,
#    'content': '胀',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57780,
#    'content': '膨',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57781,
#    'content': '孩',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57782,
#    'content': '穷',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57783,
#    'content': '裙',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57784,
#    'content': '滩',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57785,
#    'content': '谱',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57786,
#    'content': '笼',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57787,
#    'content': '诠',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57788,
#    'content': '彰',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57789,
#    'content': '芙',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57790,
#    'content': '續',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57791,
#    'content': '扇',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57792,
#    'content': '绗',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57793,
#    'content': '汪',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57794,
#    'content': '裸',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57795,
#    'content': '巢',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57796,
#    'content': '踩',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57797,
#    'content': '矢',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57798,
#    'content': '叉',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57799,
#    'content': '阖',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57800,
#    'content': '搏',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57801,
#    'content': '禅',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57802,
#    'content': '鸭',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57803,
#    'content': '咽',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57804,
#    'content': '肚',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57805,
#    'content': '吞',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57806,
#    'content': '詹',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57807,
#    'content': '蔚',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57808,
#    'content': '郑',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57809,
#    'content': '詢',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57810,
#    'content': '畔',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57811,
#    'content': '构',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57812,
#    'content': '○',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57813,
#    'content': '凤',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57814,
#    'content': '晰',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57815,
#    'content': '脘',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57816,
#    'content': '泼',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57817,
#    'content': '杉',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57818,
#    'content': '◆',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57819,
#    'content': '撬',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57820,
#    'content': '茨',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57821,
#    'content': '霾',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57822,
#    'content': '弘',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57823,
#    'content': '绪',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57824,
#    'content': '氨',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57825,
#    'content': '刃',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57826,
#    'content': '诸',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57827,
#    'content': '窄',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57828,
#    'content': '砂',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57829,
#    'content': '铸',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57830,
#    'content': '惧',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57831,
#    'content': '翎',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57832,
#    'content': '惜',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57833,
#    'content': '迮',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57834,
#    'content': '亍',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57835,
#    'content': '崔',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57836,
#    'content': '靖',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57837,
#    'content': '玺',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57838,
#    'content': '葛',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57839,
#    'content': '恰',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57840,
#    'content': '诵',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57841,
#    'content': '吟',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57842,
#    'content': '畏',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57843,
#    'content': '怨',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57844,
#    'content': '哲',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
#    'normalized': True,
#    'special': False},
#   {'id': 57845,
#    'content': '弃',
#    'single_word': False,
#    'lstrip': False,
#    'rstrip': False,
# ...
#    ['▁दोस्त', -13.417227745056152],
#    ['▁ქა', -13.417314529418944],
#    ['తూ', -13.417434692382812],
#    ['ාට', -13.417447090148926],
#    ['▁VIS', -13.417490005493164],
#    ['▁воспита', -13.417564392089844],
#    ['е', -7.520388603210449],
#    ['fa', -9.479153633117676],
#    ['جائزة', -13.417688369750977],
#    ['基本的に', -13.417694091796877],
#    ['▁ಮ್ಯಾ', -13.417736053466797],
#    ['epoca', -13.417757034301758],
#    ['▁Tên', -13.417784690856934],
#    ['zko', -11.453739166259766],
#    ['▁salsa', -13.4177885055542],
#    ['▁nettsiden', -13.417816162109377],
#    ['رقة', -13.417824745178224],
#    ['▁fort', -11.453801155090332],
#    ['▁Черно', -13.417998313903809],
#    ['φύγ', -13.41807460784912],
#    ['▁rain', -13.418183326721191],
#    ['gitur', -13.418209075927734],
#    ['ાને', -13.418275833129885],
#    ['审查', -13.418365478515623],
#    ['诉讼', -13.418371200561523],
#    ['مساعدة', -13.418375968933104],
#    ['▁диви', -13.41838264465332],
#    ['▁Paul', -11.454029083251951],
#    ['áin', -11.454060554504396],
#    ['▁x', -9.481934547424316],
#    ['저', -11.454124450683594],
#    ['▁créé', -13.418526649475098],
#    ['▁Verander', -13.418585777282717],
#    ['▁жазыл', -13.418618202209473],
#    ['ഭവ', -13.418623924255373],
#    ['▁žali', -13.41873836517334],
#    ['sebenzi', -13.41879177093506],
#    ['者は', -13.418816566467283],
#    ['▁ہوا۔', -13.418837547302246],
#    ['▁مقررات', -13.418912887573242],
#    ['▁කථා', -13.4189453125],
#    ['▁gjet', -13.419044494628906],
#    ['্টার', -13.419153213500977],
#    ['▁있음', -13.41918659210205],
#    ['▁linja', -13.419198989868164],
#    ['nka', -11.45468521118164],
#    ['▁gratuite', -13.422823905944824],
#    ['kontoret', -13.422889709472656],
#    ['ელთა', -13.422910690307615],
#    ['ခ်ိဳ', -13.422943115234377],
#    ['▁Vlad', -13.422951698303224],
#    ['随时', -13.422956466674805],
#    ['тику', -13.422981262207031],
#    ['▁Gre', -11.457530975341797],
#    ['▁Innen', -13.423035621643066],
#    ['提出的', -13.423063278198242],
#    ['kák', -13.423065185546877],
#    ['▁astept', -13.423067092895508],
#    ['▁zvezd', -13.423073768615724],
#    ['▁dolce', -13.423128128051758],
#    ['▁Bio', -11.4575834274292],
#    ['▁πρωί', -13.423213005065918],
#    ['lio', -11.45760440826416],
#    ['▁gegaan', -13.42330265045166],
#    ['▁helburu', -13.423347473144531],
#    ['▁Коз', -13.423377990722656],
#    ['▁තෙ', -13.423431396484377],
#    ['Sol', -13.423437118530272],
#    ['óban', -13.423444747924805],
#    ['▁zë', -13.42346477508545],
#    ['挖', -13.423489570617676],
#    ['▁millest', -13.42349624633789],
#    ['ងាយ', -13.423521041870115],
#    ['▁雖然', -13.423526763916016],
#    ['殼', -13.42353057861328],
#    ['döntő', -13.423534393310549],
#    ['กางเกง', -13.423545837402344],
#    ['▁Gábor', -13.423547744750977],
#    ['▁കാഴ്ച', -13.423564910888672],
#    ['になる', -11.457988739013672],
#    ['▁atlikti', -13.423579216003418],
#    ['เจอร์', -13.423603057861328],
#    ['世界各地', -13.4236478805542],
#    ['▁percuma', -13.423651695251465],
#    ['▁proceder', -13.42365837097168],
#    ['eret', -11.458375930786133],
#    ['▁hesabat', -13.423877716064451],
#    ['통신', -13.423888206481934],
#    ['▁गराउन', -13.423890113830566],
#    ['▁ret', -11.458575248718262],
#    ['▁เป็นต้น', -13.423952102661133],
#    ['▁Srbi', -13.423993110656738],
#    ['▁Perché', -13.42407512664795],
#    ['▁відділу', -13.424079895019531],
#    ['▁dog', -11.45872974395752],
#    ['▁INTE', -13.424127578735352],
#    ['▁биолог', -13.424128532409668],
#    ['▁začel', -13.424200057983398],
#    ['▁šventė', -13.424307823181152],
#    ['▁Berlin', -11.45875072479248],
#    ['kosa', -13.42434310913086],
#    ['्दी', -13.4243745803833],
#    ['▁USB', -11.45893096923828],
#    ['гүл', -13.424616813659668],
#    ['ranse', -13.424620628356934],
#    ['▁Virtu', -13.424656867980955],
#    ['شب', -13.424662590026855],
#    ['ûrê', -13.424707412719728],
#    ['▁hutan', -13.424771308898926],
#    ['παρα', -13.424793243408203],
#    ['ШЕ', -13.424907684326172],
#    ['رفت', -13.425045013427734],
#    ['מוס', -13.42508029937744],
#    ['ជួយ', -13.425200462341309],
#    ['▁göstərən', -13.425257682800291],
#    ['▁муниципал', -13.425268173217772],
#    ['▁Қазіргі', -13.425283432006836],
#    ['▁scène', -13.425291061401367],
#    ['อัพ', -13.42530345916748],
#    ['fi', -9.48967456817627],
#    ['ijo', -11.459515571594238],
#    ['▁tuilleadh', -13.425427436828612],
#    ['▁Поради', -13.425503730773926],
#    ['▁arvu', -13.425537109375],
#    ['HIT', -13.431266784667969],
#    ['▁Jy', -11.463667869567873],
#    ['▁programs', -13.43132781982422],
#    ['чылар', -13.43134880065918],
#    ['owicz', -13.431466102600098],
#    ['▁καιρό', -13.431477546691896],
#    ['ista', -9.493133544921877],
#    ['ўскай', -13.431575775146484],
#    ['trí', -13.431595802307127],
#    ['-5', -11.463788986206056],
#    ['สภา', -13.431684494018556],
#    ['▁Gesundheit', -13.431781768798828],
#    ['野', -11.464094161987305],
#    ['▁өзгерістер', -13.432014465332031],
#    ['▁inveni', -13.43209171295166],
#    ['Монгол', -13.432161331176758],
#    ['素', -11.464173316955566],
#    ['螢幕', -13.432183265686035],
#    ['スタイル', -13.432186126708984],
#    ['▁நம்ம', -13.432188987731934],
#    ['▁Movie', -11.46428680419922],
#    ['▁mbi', -11.46432113647461],
#    ['▁hətta', -13.432245254516602],
#    ['▁долг', -13.4322509765625],
#    ['▁bladsy', -13.43226146697998],
#    ['列表', -13.43227481842041],
#    ['▁одсто', -13.43228816986084],
#    ['▁stii', -13.432317733764648],
#    ['▁recuperación', -13.432333946228027],
#    ['对', -9.493570327758787],
#    ['出来', -11.464338302612305],
#    ['▁වන්න', -13.432381629943848],
#    ['vaks', -13.432429313659668],
#    ['▁метода', -13.432509422302246],
#    ['▁고려', -13.432689666748049],
#    ['▁ຈັດ', -13.432692527770996],
#    ['mático', -13.43271827697754],
#    ['▁զոհ', -13.432748794555664],
#    ['▁хама', -13.43277645111084],
#    ['▁хү', -13.432847023010254],
#    ['▁meslek', -13.432910919189451],
#    ['派', -11.464883804321287],
#    ['पत्', -13.433192253112791],
#    ['▁кайсы', -13.43326473236084],
#    ['▁максат', -13.433298110961914],
#    ['▁hämta', -13.433326721191406],
#    ['િસ', -13.433353424072266],
#    ['▁kotona', -13.433378219604492],
#    ['פתי', -13.433452606201172],
#    ['Ազատություն', -13.433459281921388],
#    ['冷', -11.465110778808594],
#    ['dul', -11.46518325805664],
#    ['▁dienen', -13.433761596679688],
#    ['▁resolve', -13.433855056762695],
#    ['Жи', -13.433867454528809],
#    ['વાળા', -13.433908462524414],
#    ['▁Thần', -13.433937072753906],
#    ['tuar', -11.465579986572266],
#    ['ping', -11.465919494628906],
#    ['Ձ', -13.43405818939209],
#    ['geht', -13.434134483337402],
#    ['▁insect', -13.434159278869627],
#    ['▁enako', -13.434165000915527],
#    ['▁Oo', -11.465964317321776],
#    ['▁ਸਿਰ', -13.434250831604004],
#    ['▁mfano', -13.434306144714355],
#    ['▁Ró', -13.434337615966797],
#    ['▁निगम', -13.434345245361328],
#    ['LAY', -13.434436798095703],
#    ['ົ້', -13.434470176696776],
#    ['▁ο', -9.495956420898438],
#    ['поз', -13.434493064880373],
#    ['321', -13.434532165527344],
#    ['▁Duniya', -13.434532165527344],
#    ['▁radhë', -13.434603691101074],
#    ['▁standa', -13.434706687927246],
#    ['▁district', -13.434707641601562],
#    ['▁ട്ട', -13.43471622467041],
#    ['etate', -13.43472671508789],
#    ['ອະ', -13.434755325317385],
#    ['▁Pie', -11.46630573272705],
#    ['скре', -13.434774398803713],
#    ['RAI', -13.434850692749023],
#    ['斯坦', -13.434865951538086],
#    ['срочно', -13.43486785888672],
#    ['ampu', -13.434903144836426],
#    ['▁overal', -13.434903144836426],
#    ['▁madeira', -13.434931755065918],
#    ['ով՝', -13.434951782226562],
#    ['類似', -13.43520164489746],
#    ['▁खि', -13.435227394104004],
#    ['▁gắn', -13.435325622558594],
#    ['交流', -11.46656894683838],
#    ['gelt', -13.435465812683104],
#    ['▁원', -11.466634750366213],
#    ['▁tienda', -13.43548583984375],
#    ['▁22', -9.496496200561523],
#    ['ολογίας', -13.435585975646973],
#    ['▁пережива', -13.43560028076172],
#    ['凭', -13.435630798339844],
#    ['优惠', -13.43563175201416],
#    ['▁keturi', -13.435639381408691],
#    ['sc', -11.466904640197754],
#    ...],
#   'byte_fallback': False}}

# %%
vocab = tokenizer_data["model"]["vocab"]
len(vocab), vocab[100]
# Out:
# (57522, ['เดอร์', -13.401432037353516])

# %%
import re

# %%
def is_chinese_or_english(token):
    pattern = re.compile("^[\u4e00-\u9fa5a-zA-Z]+$")
    return bool(pattern.match(token))

def is_valid_token(token):
    """
    中文、英文、数字、符号
    :param token:
    :return:
    """
    #pattern = re.compile("^[\u4e00-\u9fa5a-zA-Z0-9\s`~!@#$%^&Ω🔞*()-_+={}[\]:;\"'<>,.?/]+$")
    pattern = re.compile("^[\u4e00-\u9fa5a-zA-Z0-9\s`~!@#$%^&Ω🔞*()≈≡≠＝<>＜＞≮≯∷±＋－×÷／∫∮∝∞∧∨∑∏∪∩∈∵∴⊥‖∠⌒≌∽√（）【】｛｝ⅠⅡ⊕⊙∥αβγδεζηθΔ+={}[\]:;\"'<>,.?/]+$")

    return bool(pattern.match(token))

input_str = "3.2"
is_chinese_or_english(input_str), is_valid_token(input_str), langid.classify(input_str)
# Out:
# (False, True, ('en', 9.061840057373047))

# %%
new_vocab, filtered_vocab = [], []
for v in tqdm(vocab):
    token = v[0].replace("▁", "")
    lang = langid.classify(token)
    is_ch_or_en = is_chinese_or_english(token)
    is_valid = is_chinese_or_english(token)
    flag = True if lang[0] in ["en", "zh"] else False
    if is_ch_or_en or is_valid or flag:
        new_vocab.append(v)
    else:
        filtered_vocab.append(v)
# Out:
# 100%|██████████| 57522/57522 [01:22<00:00, 694.19it/s]

# %%
len(new_vocab), len(filtered_vocab)
with open("new_vocab.txt", "w", encoding="utf-8") as f1,\
    open("filtered_vocab.txt", "w", encoding="utf-8") as f2:
    vocab_1 = [v[0] for v in new_vocab]
    vocab_2 = [v[0] for v in filtered_vocab]
    f1.write("\n".join(vocab_1))
    f2.write("\n".join(vocab_2))

# %%
new_vocab[:-100], len(new_vocab)
# Out:
# ([['<s>', 0.0],
#   ['<pad>', 0.0],
#   ['</s>', 0.0],
#   ['<unk>', 0.0],
#   ['a', -5.5477118492126465],
#   ['▁_', -7.502312660217285],
#   ['▁plus', -9.463733673095703],
#   ['II', -11.439068794250488],
#   ['协', -13.465469360351562],
#   ['2012', -11.492591857910156],
#   ['▁Reforma', -13.465529441833496],
#   ['種', -11.492602348327637],
#   ['▁bəy', -13.465703010559082],
#   ['누', -13.465737342834473],
#   ['▁bizler', -13.4657564163208],
#   ['▁school', -11.49265956878662],
#   ['nah', -11.49273681640625],
#   ['加油', -13.465953826904297],
#   ['▁Ham', -11.492804527282717],
#   ['▁Zudem', -13.465987205505373],
#   ['▁gaman', -13.466017723083496],
#   ['400', -11.492900848388672],
#   ['▁ne', -7.563854217529297],
#   ['▁fa', -9.527026176452637],
#   ['▁policaj', -13.466214179992676],
#   ['ttuna', -13.46630859375],
#   ['▁bewegen', -13.466320037841797],
#   ['▁oficina', -13.4663667678833],
#   ['▁recebi', -13.466477394104004],
#   ['▁tap', -11.49323844909668],
#   ['3.2', -13.466510772705078],
#   ['▁truk', -13.466548919677734],
#   ...],
#  40239)

# %%
added_tokens = tokenizer_data["added_tokens"]
new_add_tokens = []
new_added_tokens_start_id = len(new_vocab) - 1
for t in added_tokens:
    if t["id"] in [0, 1, 2, 3]:
        new_add_tokens.append(t)
        continue
    t["id"] = new_added_tokens_start_id
    new_add_tokens.append(t)
    new_added_tokens_start_id += 1

# %%
new_add_tokens[:100]
# Out:
# [{'id': 0,
#   'content': '<s>',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': False,
#   'special': True},
#  {'id': 1,
#   'content': '<pad>',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': False,
#   'special': True},
#  {'id': 2,
#   'content': '</s>',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': False,
#   'special': True},
#  {'id': 3,
#   'content': '<unk>',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': False,
#   'special': True},
#  {'id': 40238,
#   'content': '<mask>',
#   'single_word': False,
#   'lstrip': True,
#   'rstrip': False,
#   'normalized': True,
#   'special': True},
#  {'id': 40239,
#   'content': '<sep/>',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40240,
#   'content': '<s_iitcdip>',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': False,
#   'special': True},
#  {'id': 40241,
#   'content': '<s_synthdog>',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': False,
#   'special': True},
#  {'id': 40242,
#   'content': '</n>',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40243,
#   'content': '册',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40244,
#   'content': '1',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40245,
#   'content': '茄',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40246,
#   'content': '链',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40247,
#   'content': '枢',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40248,
#   'content': '摘',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40249,
#   'content': '绞',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40250,
#   'content': '驱',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40251,
#   'content': '循',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40252,
#   'content': '央',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40253,
#   'content': '鸣',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40254,
#   'content': '蜂',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40255,
#   'content': '堵',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40256,
#   'content': '针',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40257,
#   'content': '泵',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40258,
#   'content': '灾',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40259,
#   'content': '扑',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40260,
#   'content': '饼',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40261,
#   'content': '滇',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40262,
#   'content': '酥',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40263,
#   'content': '咸',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40264,
#   'content': '脉',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40265,
#   'content': '烘',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40266,
#   'content': '陷',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40267,
#   'content': '湘',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40268,
#   'content': '呵',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40269,
#   'content': '怡',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40270,
#   'content': '遮',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40271,
#   'content': '铝',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40272,
#   'content': '兽',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40273,
#   'content': '译',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40274,
#   'content': '润',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40275,
#   'content': '①',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40276,
#   'content': '●',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40277,
#   'content': '尘',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40278,
#   'content': '滤',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40279,
#   'content': '纹',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40280,
#   'content': '暂',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40281,
#   'content': '慎',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40282,
#   'content': '析',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40283,
#   'content': '颜',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40284,
#   'content': '验',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40285,
#   'content': '跃',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40286,
#   'content': '阶',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40287,
#   'content': '键',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40288,
#   'content': '≤',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40289,
#   'content': '胶',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40290,
#   'content': '橡',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40291,
#   'content': '阔',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40292,
#   'content': '舱',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40293,
#   'content': '览',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40294,
#   'content': '寸',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40295,
#   'content': '伏',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40296,
#   'content': '鼎',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40297,
#   'content': '螺',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40298,
#   'content': '扩',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40299,
#   'content': '芯',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40300,
#   'content': '址',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40301,
#   'content': '径',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40302,
#   'content': '络',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40303,
#   'content': '≥',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40304,
#   'content': '↑',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40305,
#   'content': '悬',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40306,
#   'content': '唑',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40307,
#   'content': '筛',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40308,
#   'content': '蝴',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40309,
#   'content': '蝶',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40310,
#   'content': '輸',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40311,
#   'content': '贯',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40312,
#   'content': '卸',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40313,
#   'content': '夹',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40314,
#   'content': '盲',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40315,
#   'content': '毫',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40316,
#   'content': '挽',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40317,
#   'content': '躺',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40318,
#   'content': '训',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40319,
#   'content': '辉',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40320,
#   'content': '枕',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40321,
#   'content': '励',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40322,
#   'content': '偿',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40323,
#   'content': '拨',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40324,
#   'content': '曝',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40325,
#   'content': '阅',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40326,
#   'content': '悦',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40327,
#   'content': '竭',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40328,
#   'content': '涵',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40329,
#   'content': '烦',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40330,
#   'content': '攀',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40331,
#   'content': '■',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40332,
#   'content': '惯',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False},
#  {'id': 40333,
#   'content': '椅',
#   'single_word': False,
#   'lstrip': False,
#   'rstrip': False,
#   'normalized': True,
#   'special': False}]

# %%
import copy
new_tokenizer_data = copy.deepcopy(tokenizer_data)
new_tokenizer_data["model"]["vocab"] = new_vocab
new_tokenizer_data["added_tokens"] = new_add_tokens

new_tokenizer_config_data = copy.deepcopy(tokenizer3_config_data)
new_tokenizer_config_data["added_tokens"] = new_add_tokens
new_tokenizer_config_data["added_tokens_decoder"] = new_add_tokens

with open("./donut-zh/tokenizer.json", "w", encoding="utf-8") as f1,\
        open("./donut-zh/tokenizer_config.json", "w", encoding="utf-8") as f2:
    f1.write(json.dumps(new_tokenizer_data, ensure_ascii=False, indent=2))
    f2.write(json.dumps(new_tokenizer_config_data, ensure_ascii=False, indent=2))

# %%
MP4 = "./donut-zh"
tokenizer4 = AutoTokenizer.from_pretrained(MP4)

# %%
text = "中国平安是世界500强"
tokenizer3.tokenize(text), tokenizer4.tokenize(text)
# Out:
# (['中国', '平安', '是', '世界', '500', '强'], ['中国', '平安', '是', '世界', '500', '强'])

# %%
tokenizer3.convert_tokens_to_ids(tokenizer3.tokenize(text)), tokenizer4.convert_tokens_to_ids(tokenizer4.tokenize(text))
# Out:
# ([20741, 53214, 37830, 36669, 40556, 48372],
#  [11153, 36718, 23175, 22148, 25606, 32483])

# %%
len(tokenizer4.get_vocab())
# Out:
# 41608

# %%
save_path = 'donut-zh-model'
# pruner = BloomVocabularyPruner()
pruner = DonutVocabularyPruner()
# 裁剪
pruner.prune(MP3, MP4, save_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 3
#       1 save_path = 'donut-zh-model'
#       2 # pruner = BloomVocabularyPruner()
# ----> 3 pruner = DonutVocabularyPruner()
#       4 # 裁剪
#       5 pruner.prune(MP3, MP4, save_path)
#
# NameError: name 'DonutVocabularyPruner' is not defined
