# %% [markdown]
# ### 1.动机
# - donut使用了多语言的词表, 实际使用中大多情况下都是只有中文和英文词表

# %% [markdown]
# ### 2.bloom模型

# %%
from transformers import AutoTokenizer
from vocabulary_pruner import VocabularyPruner
from tqdm import tqdm

# %%
MP1 = "J:/model/bigscience-bloom-560m"
MP2 = "J:/model/YeungNLP-bloom-396m-zh"

# %%
class BloomVocabularyPruner(VocabularyPruner):

    def update_ebeddings(self, model, new2old_token_id, new_embeds, new_lm_head):
        for token_id, old_token_id in tqdm(new2old_token_id.items()):
            new_embeds.weight.data[token_id] = model.transformer.word_embeddings.weight.data[old_token_id]
            new_lm_head.weight.data[token_id] = model.lm_head.weight.data[old_token_id]
        model.transformer.word_embeddings.weight = new_embeds.weight
        model.lm_head.weight = new_lm_head.weight

# %%
save_path = 'bloom-396m-zh'
pruner = BloomVocabularyPruner()
# 裁剪
pruner.prune(MP1, MP2, save_path)
# 检查裁剪的模型与原模型是否一致
pruner.check(MP1, save_path, text='长风破浪会有时')
# Out:
# 100%|██████████| 46145/46145 [00:00<00:00, 1648042.90it/s]
# new_tokenizer is subset of old_tokenizer
# 100%|██████████| 46145/46145 [00:00<00:00, 1214277.74it/s]
# Total params of original model: 559.21M
# 100%|██████████| 46145/46145 [00:01<00:00, 37781.42it/s]
# Total params of new model : 396.82M
# 词表缩小为原来的:18.41%
# 模型参数量缩小为原来的:70.96000000000001%
# old_output:['长风破浪会有时,直挂云帆济沧海。 愿你,在人生的旅途中,能遇见最美的风景,遇见最美的自己。</s>']
# new_output:['长风破浪会有时,直挂云帆济沧海。 愿你,在人生的旅途中,能遇见最美的风景,遇见最美的自己。</s>']
# output is same, succeed to prune.

# %% [markdown]
# ### 3.donut模型
# - step1: 构建删减后的tokenizer.json

# %%
from transformers import DonutProcessor
MP3 = "J:/model/mllm-model/donut-pretrain/20240102/pl-checkpoint-232000-ned-0.8460975410122905"

# %%
tokenizer3 = AutoTokenizer.from_pretrained(MP3)
#processor3 = DonutProcessor.from_pretrained(MP3)

# %%
tokenizer3.get_vocab()
# Out:
# {'荣': 47511,
#  'bun': 17454,
#  'ozni': 54707,
#  '▁ayaw': 10556,
#  'ることができ': 12365,
#  '▁Lex': 57271,
#  '計': 26909,
#  '株式会社': 55906,
#  '一個': 40681,
#  '▁Girls': 46597,
#  '탰': 33221,
#  '圧': 52816,
#  '纲': 12021,
#  '胪': 58465,
#  '技術': 51918,
#  '▁raska': 4659,
#  '即時': 50723,
#  '▁позив': 2391,
#  '泌': 58012,
#  '-16': 8662,
#  '▁recept': 1722,
#  '▁city': 34355,
#  '▁raf': 42484,
#  'elin': 38740,
#  '▁humanist': 8816,
#  '遽': 29999,
#  'ede': 40247,
#  '▁ڇڪ': 25766,
#  '蒞': 29277,
#  '冉': 29767,
#  '한국': 40102,
#  '▁سبحان': 22675,
#  '叙': 58062,
#  '▁neviens': 13426,
#  'பட்ட': 4220,
#  'ຢ້ຽມ': 28152,
#  'zare': 42752,
#  '浣': 30669,
#  'sep': 49398,
#  'ANZA': 54156,
#  '齦': 33577,
#  '▁devi': 35885,
#  '▁изгради': 12382,
#  '▁spill': 22475,
#  'ometr': 54288,
#  '讨': 57959,
#  '紉': 33483,
#  '▁שוקולד': 19909,
#  'Ko': 5337,
#  '▁Kro': 35211,
#  '打出': 18869,
#  '荤': 31547,
#  '轲': 32406,
#  'եհ': 18732,
#  '▁dia': 54308,
#  'pano': 45934,
#  '见到': 54874,
#  'strahl': 14073,
#  '▁ഒഴിവാക്കുക': 19181,
#  '明るい': 27577,
#  '▁знали': 2929,
#  '▁natura': 10523,
#  '▁Yr': 38110,
#  '贵': 37246,
#  'α': 10719,
#  'SB': 38274,
#  '▁ce': 39678,
#  '▁prizor': 11914,
#  'spar': 34380,
#  'устойчив': 9302,
#  '¬': 38436,
#  '高級': 49419,
#  '억원': 56074,
#  'ヶ': 21646,
#  'letter': 47121,
#  '▁noapte': 57329,
#  '▁kapsul': 8773,
#  '呕': 29278,
#  '中の': 41995,
#  '/4': 16908,
#  '++': 38540,
#  'alen': 46868,
#  '▁Og': 36517,
#  '▁music': 21367,
#  'क्षय': 22981,
#  '▁affida': 54998,
#  '▁Ø': 8526,
#  '栓': 27573,
#  '裊': 33289,
#  '▁vaya': 7894,
#  '团结': 56453,
#  '▁Smith': 38716,
#  'hand': 5879,
#  'գործ': 56916,
#  'liti': 35385,
#  '曬': 58550,
#  'Car': 25259,
#  '▁amp': 41746,
#  '▁Mao': 1749,
#  '▁requirements': 56657,
#  'إدارة': 20654,
#  '▁близу': 18359,
#  '野': 909,
#  '▁전환': 12580,
#  '积': 44063,
#  '日前': 35639,
#  '▁interpret': 35603,
#  '17)': 46111,
#  '娣': 31406,
#  '▁KAL': 51555,
#  '▁되고': 54149,
#  '▁Jord': 52030,
#  'CR': 26411,
#  '▁bland': 6545,
#  '▁մահացել': 25195,
#  '▁East': 29851,
#  'itinerari': 3492,
#  'друго': 11036,
#  'jenga': 13199,
#  '掲示板': 20083,
#  '▁Vladimír': 20471,
#  'mbu': 18886,
#  '▁Γιώργο': 13464,
#  '呼': 26701,
#  '▁rasp': 46645,
#  '▁moment': 36191,
#  '▁als': 50331,
#  'mando': 53793,
#  'otin': 54622,
#  'give': 56564,
#  '▁요소': 9883,
#  '大会': 27594,
#  'ـــــ': 13615,
#  'ಂತೂ': 22514,
#  '落實': 8456,
#  '▁Vaj': 54244,
#  '好多': 52688,
#  'اهو': 6788,
#  '▁Mange': 36954,
#  '▁زلزل': 18219,
#  '▁Stati': 49664,
#  '▁daily': 36513,
#  'ex': 37179,
#  '宛': 58068,
#  'noma': 36235,
#  '▁Partido': 50745,
#  '希望能': 56194,
#  '챤': 33098,
#  '邏': 33795,
#  '쪽': 39236,
#  'στες': 3457,
#  'බිම': 21003,
#  '▁홍': 48854,
#  '睹': 21433,
#  'हॅ': 24341,
#  '▁hösten': 6679,
#  '▁LINE': 7463,
#  '▁Punto': 18391,
#  '譲': 22848,
#  '▁gc': 25682,
#  '▁disposi': 55305,
#  '쑥': 29544,
#  '▁최고의': 51848,
#  '着': 13258,
#  'rimo': 46436,
#  '盟': 48937,
#  'ვედ': 8293,
#  '▁Кыргызстанга': 22647,
#  'do': 30251,
#  'vela': 43553,
#  '▁intermedi': 52690,
#  'š': 51959,
#  '▁Under': 56562,
#  '첼': 29435,
#  '枉': 28885,
#  '▁vent': 35922,
#  'amin': 40368,
#  'år': 9112,
#  'சோ': 14586,
#  '董': 56581,
#  '▁Peng': 34909,
#  '圾': 33833,
#  'thro': 40360,
#  '風險': 49907,
#  'זיקה': 6804,
#  '▁карты': 4359,
#  '▁atento': 2456,
#  '▁предпоч': 11245,
#  'לר': 4903,
#  '▁बॉस': 14413,
#  '▁Styr': 53475,
#  '身': 35684,
#  '发展': 37142,
#  '泅': 58651,
#  '▁Kontrolle': 3121,
#  '▁autostrad': 8254,
#  '▁seçimi': 12349,
#  '櫚': 29940,
#  'သမ္မတ': 7291,
#  'ରାଇ': 12678,
#  'ぐ': 40748,
#  '網站': 8414,
#  '供应商': 457,
#  '▁мэдэх': 57190,
#  'check': 51676,
#  '▁Skil': 15274,
#  '▁գտել': 27819,
#  '侵犯': 9003,
#  '▁nim': 14070,
#  '\uf0b7': 32943,
#  '▁државно': 5626,
#  'Ez': 51188,
#  'laps': 56511,
#  '▁soldi': 51890,
#  '▁passer': 3508,
#  'ș': 56248,
#  'zal': 11904,
#  '噁': 29625,
#  '舊': 39395,
#  'olo': 50827,
#  '并不': 19845,
#  '▁Abd': 47260,
#  '▁ortiq': 1777,
#  '▁Wow': 44105,
#  '▁ਫਿ': 25017,
#  '杂志': 2847,
#  '様': 26348,
#  '付': 2368,
#  '自分の': 4430,
#  'bbe': 39642,
#  'KUM': 4364,
#  '▁Marta': 46939,
#  '▁artikoloj': 17530,
#  '▁Şö': 26514,
#  '看着': 34390,
#  '▁tilkynnt': 28743,
#  '2002': 40139,
#  'isen': 45612,
#  '长的': 53265,
#  'dav': 17685,
#  '▁transmit': 49790,
#  '▁procesul': 6240,
#  '▁composición': 14480,
#  '▁taxa': 38183,
#  '煌': 57720,
#  'ovanou': 9045,
#  '寶': 32987,
#  '▁참석': 54849,
#  '矾': 33073,
#  '▁Immer': 56144,
#  'スペシャル': 28765,
#  '鋅': 29891,
#  '盡': 32256,
#  '映画': 39422,
#  '簡': 37667,
#  '▁evin': 52341,
#  '▁Osteo': 26508,
#  '▁Aziz': 40281,
#  '▁85': 55879,
#  '▁IC': 48945,
#  '▁Stoltenberg': 26817,
#  '馄': 33423,
#  'elle': 24146,
#  '堰': 58214,
#  '菩薩': 26975,
#  '▁blanc': 39204,
#  '▁삼': 44183,
#  'wki': 48745,
#  'lange': 43847,
#  '舒適': 44082,
#  '鹑': 31829,
#  'sco': 5218,
#  '▁przeczyta': 11802,
#  '▁Legion': 23149,
#  'rani': 34366,
#  '事業': 25944,
#  '▁envoyé': 15717,
#  '膨': 57780,
#  '▁цените': 402,
#  'dā': 42616,
#  '▁pier': 46628,
#  '▁bytu': 2311,
#  '▁Kart': 40345,
#  'krok': 17391,
#  'いった': 55111,
#  '▁You': 34158,
#  '坵': 32756,
#  '負責': 47517,
#  '▁تستطيع': 6071,
#  '▁sent': 55789,
#  '教材': 1496,
#  'ová': 38641,
#  '▁normal': 38232,
#  '▁subordin': 14921,
#  'uq': 36168,
#  '▁등에': 55549,
#  '▁0,7': 57004,
#  '哂': 31346,
#  '▁Қоғам': 24887,
#  'IGA': 46833,
#  '댓': 29059,
#  'tric': 46871,
#  '不可能': 39612,
#  '▁acreditar': 14502,
#  '▁Meg': 1802,
#  '▁inferior': 41010,
#  'ിറങ്ങിയ': 14213,
#  'べき': 53329,
#  '基地': 37504,
#  'යො': 1982,
#  '蛾': 30777,
#  'ég': 37595,
#  '岙': 58557,
#  '▁പ്രീ': 20537,
#  '臣': 57928,
#  'byl': 50009,
#  '▁inter': 20952,
#  'KS': 22267,
#  '厲害': 19217,
#  '倜': 32939,
#  'icis': 49446,
#  '▁sastāvdaļa': 24768,
#  '▁fiziki': 5537,
#  '▁koncentrál': 25905,
#  'DU': 19084,
#  '▁Polo': 36657,
#  '大きく': 49677,
#  '୧୨': 13027,
#  'raga': 40447,
#  '▁Che': 43065,
#  '▁World': 48225,
#  'messen': 49305,
#  'päivinä': 26294,
#  'ismo': 36268,
#  '▁Kore': 39067,
#  '탄': 39292,
#  '无数': 5214,
#  '移': 22725,
#  '▁4.3': 52216,
#  '▁hi': 6823,
#  '▁Nemo': 50294,
#  '▁Sak': 26382,
#  '▁sto': 37621,
#  '▁можам': 7405,
#  '삶': 30103,
#  'ໟ': 32624,
#  '▁Gott': 38959,
#  '▁diteruskan': 28435,
#  '▁IE': 50870,
#  '堤': 58137,
#  'してしまいました': 24001,
#  'xana': 51391,
#  '▁gonna': 7969,
#  'inda': 26161,
#  'จอด': 2931,
#  '明白': 39555,
#  '▁His': 19733,
#  '▁날': 25276,
#  '깼': 33329,
#  '鮑': 28372,
#  '▁gücləndir': 22926,
#  'になり': 40027,
#  '▁intent': 51621,
#  'ありました': 8394,
#  '▁Kama': 37365,
#  '美容': 38627,
#  '▁rettigheder': 11417,
#  '▁출시': 51881,
#  '▁clar': 16809,
#  '坞': 31156,
#  '嘘': 58242,
#  '燐': 32686,
#  '梢': 30258,
#  '▁Demir': 45947,
#  'さを': 55168,
#  '▁भाषण': 6606,
#  '来的': 40733,
#  'になった': 27361,
#  'ΩΣ': 4218,
#  '▁suelo': 1908,
#  '▁nêu': 9850,
#  '▁det': 11491,
#  '且': 57491,
#  '▁Au': 45051,
#  '▁cost': 2674,
#  '了一下': 47376,
#  '▁любви': 2899,
#  '敝': 30465,
#  '▁loc': 49226,
#  '▁tang': 33955,
#  '▁ovi': 2135,
#  '딩': 43075,
#  'いて': 9798,
#  '▁Mtwara': 27296,
#  'käsi': 5483,
#  '▁Batang': 18358,
#  '專家': 44757,
#  '▁Dynamics': 20893,
#  '지역': 46555,
#  '▁Beli': 37669,
#  '速': 13429,
#  '▁행정': 3433,
#  '▁orient': 27761,
#  '▁mimi': 38615,
#  '▁bone': 36921,
#  '在': 24186,
#  'wikkel': 14400,
#  '”': 46818,
#  '▁tibi': 36371,
#  '/25': 56809,
#  '▁Mirziyoyev': 17770,
#  '▁dal': 14931,
#  '▁variable': 51399,
#  '▁Rum': 35025,
#  '複': 58344,
#  '370': 49537,
#  '្ត': 10413,
#  '▁prae': 4825,
#  '黏': 5618,
#  '给了': 53790,
#  'zze': 28736,
#  'laki': 20079,
#  '蟲': 54648,
#  '▁khan': 49264,
#  '૧૭': 11329,
#  '畿': 29847,
#  'foretak': 24222,
#  '▁byrjað': 22731,
#  '▁Gabon': 17449,
#  '▁фантасти': 1444,
#  'ట్టే': 14215,
#  '▁effective': 46278,
#  '▁bayaran': 6962,
#  '▁Telekom': 53101,
#  '▁אָנ': 7905,
#  '鉑': 30668,
#  '凸': 19375,
#  'lähetys': 25920,
#  '▁англ': 5996,
#  '▁Guru': 34055,
#  '▁origin': 46089,
#  '▁Mette': 6248,
#  '▁Hä': 35376,
#  '言い': 43455,
#  '▁Markus': 2885,
#  'kar': 3880,
#  '紘': 32213,
#  '胍': 32597,
#  '▁heavy': 57295,
#  '视野': 17658,
#  '▁Living': 40845,
#  '枝': 52240,
#  'zono': 48764,
#  '▁EH': 55556,
#  '▁Pradesh': 25478,
#  '▁bab': 28014,
#  'ສົມທົບ': 28107,
#  '無料': 37029,
#  '▁Eikö': 23877,
#  'etes': 36067,
#  '▁lesbisk': 69,
#  'сър': 23813,
#  '倬': 58317,
#  '蕒': 58817,
#  '▁Ант': 6189,
#  '▁Army': 6561,
#  '▁felhasznál': 11707,
#  'dul': 948,
#  '▁SAY': 12772,
#  '▁Fleisch': 15695,
#  'Ỳ': 29880,
#  'EST': 25228,
#  '▁CA': 28004,
#  'ISE': 54567,
#  'をやって': 20746,
#  '▁colore': 44995,
#  '结束后': 13631,
#  'off': 15641,
#  '愚': 58014,
#  'là': 14439,
#  '▁piešķir': 15604,
#  '▁trad': 37607,
#  'vidi': 39828,
#  'ləşməsi': 21582,
#  '嘍': 31022,
#  'ắ': 33846,
#  'tik': 11718,
#  '监督': 41191,
#  'じゃ': 46591,
#  'cine': 37216,
#  '▁අස්': 4631,
#  'いけない': 17865,
#  '▁iris': 56777,
#  'ଖଣ୍ଡ': 10436,
#  'sé': 26768,
#  '▁BR': 28248,
#  '▁desberdin': 2484,
#  '▁adolescente': 8984,
#  '▁6.3': 9102,
#  '▁classic': 44480,
#  '15': 18942,
#  '▁Johnson': 46044,
#  '▁тонко': 23074,
#  '▁245': 5669,
#  '▁Ul': 11878,
#  'もある': 37739,
#  '▁Duration': 52111,
#  'stron': 53625,
#  '因为': 41891,
#  '璐': 29449,
#  '✙': 58775,
#  '▁Karimov': 7380,
#  '▁ölkələrdə': 9721,
#  '▁Nim': 45958,
#  '見学': 19691,
#  '▁славян': 7263,
#  '▁Add': 35482,
#  '▁détail': 12014,
#  '▁درصدی': 13317,
#  '▁酒店位於': 28721,
#  '▁Logo': 38355,
#  '”、“': 46963,
#  'ሄዱ': 16403,
#  'ымыздың': 15757,
#  'Shop': 51858,
#  '령': 34056,
#  '▁długi': 2976,
#  '▁전시': 56959,
#  '▁metri': 34652,
#  '▁Balance': 7723,
#  '↑': 57587,
#  '饪': 33697,
#  '每月': 53766,
#  'ting': 20476,
#  '困擾': 18002,
#  '赢得了': 22089,
#  '▁jüngst': 27124,
#  '屓': 33153,
#  'olin': 46443,
#  '▁after': 49536,
#  'ρεί': 12550,
#  'お客さま': 22847,
#  '▁Movies': 53254,
#  '▁info': 35828,
#  'fus': 50584,
#  '▁válik': 12077,
#  '衝撃': 28458,
#  '▁tendência': 7668,
#  '校园': 56597,
#  'ses': 45892,
#  'дэнт': 12820,
#  '▁privati': 55670,
#  '▁Jaya': 42970,
#  'أفلام': 10392,
#  '▁proběhl': 25881,
#  '莺': 31362,
#  'CIONES': 25548,
#  '▁cura': 9613,
#  'tico': 9483,
#  'prav': 51332,
#  '资产': 36718,
#  '▁Lý': 41281,
#  'sur': 49532,
#  'ron': 20198,
#  '▁series': 38300,
#  '▁tot': 4671,
#  '▁Poker': 38265,
#  '种': 16393,
#  'အန္': 23518,
#  '▁будући': 17336,
#  '根本': 26448,
#  '团队': 23274,
#  '▁Iza': 42847,
#  '▁Macron': 54489,
#  '▁معلوماتو': 14069,
#  'wani': 25415,
#  '食': 46321,
#  '▁taldea': 4115,
#  '抓住': 54475,
#  '▁Russ': 43374,
#  'まい': 55038,
#  '▁skrivit': 7146,
#  '寬': 45647,
#  '.3.': 35316,
#  '到底': 35633,
#  '▁pang': 54209,
#  '抬': 364,
#  '▁analogi': 15253,
#  '化學': 3450,
#  'બાર': 852,
#  'лорду': 21954,
#  'लौ': 6745,
#  '▁مطالعات': 5436,
#  'alueella': 15379,
#  '定期': 42025,
#  '▁வந்தது': 6051,
#  '▁Arri': 47729,
#  '▁Dem': 39251,
#  'maq': 53837,
#  '▁hal': 19597,
#  '쳇': 32259,
#  '▁sperma': 43796,
#  '▁Fre': 24871,
#  'vri': 40150,
#  'jung': 7573,
#  '▁lei': 40617,
#  '▁Spektrum': 27755,
#  'コマンド': 24835,
#  'sá': 36072,
#  '▁weeks': 39846,
#  '凰': 28997,
#  '谜': 29035,
#  '▁pantalon': 2483,
#  '▁Gewerbe': 23023,
#  '780': 57325,
#  '▁тұрақты': 466,
#  '▁Language': 53200,
#  '▁HIV': 38848,
#  '倾': 1903,
#  '▁ਵਿਚੋਂ': 16817,
#  '▁Wan': 39725,
#  'ほしい': 57212,
#  'ici': 34308,
#  '埃及': 10022,
#  '▁android': 44409,
#  'excursion': 18415,
#  '鰲': 31616,
#  '▁suit': 46461,
#  '▁фамил': 8530,
#  '▁irodalmi': 27707,
#  'អន្តរជាតិ': 12278,
#  '▁totalitar': 15554,
#  '▁motív': 15945,
#  '▁Kerk': 45807,
#  '▁좋아': 48550,
#  '▁tunay': 1405,
#  '螂': 58163,
#  'ជនជាតិ': 143,
#  '▁жеңил': 16353,
#  '달러': 54038,
#  '▁өткізу': 2262,
#  '委員': 4194,
#  'rød': 52424,
#  '▁Duitse': 5302,
#  'Up': 44006,
#  'geladen': 15224,
#  '許多': 27187,
#  'luck': 14416,
#  'oqrafiya': 24592,
#  '▁handlekurv': 28298,
#  '▁onay': 6790,
#  '▁peggio': 8139,
#  'ປັບປຸງ': 6529,
#  '▁Price': 42316,
#  '▁Diana': 47535,
#  'ఫె': 2490,
#  '▁Trans': 2741,
#  '▁ажилла': 4902,
#  'doni': 52267,
#  'lara': 39365,
#  '▁nostri': 4697,
#  'friend': 53343,
#  '▁colegi': 57182,
#  '▁Minder': 9734,
#  'સ્તર': 21498,
#  'パー': 40869,
#  'െത്തി': 6023,
#  '他表示': 8358,
#  '顛': 27438,
#  '푹': 29863,
#  '▁Luca': 55517,
#  '9/': 55577,
#  '▁Srbi': 707,
#  '翟': 30122,
#  'rei': 56401,
#  '这么多': 56724,
#  'vention': 45285,
#  '土地': 23445,
#  'ås': 45415,
#  '件': 49240,
#  '狮': 57939,
#  '.10.': 480,
#  '込み': 48451,
#  '大丈夫': 54281,
#  '鯧': 32304,
#  '▁Gi': 43552,
#  '▁नोटिफिकेशन': 872,
#  '像是': 40463,
#  'kind': 48740,
#  '▁TC': 52435,
#  '吭': 30316,
#  '▁лежи': 15608,
#  '▁6,5': 53042,
#  '▁About': 45163,
#  '▁hiervan': 8029,
#  '不再': 39361,
#  'alam': 9805,
#  '▁minučių': 15495,
#  'කැ': 15593,
#  '溱': 32062,
#  '队友': 21816,
#  '奔': 46764,
#  'ІІ': 9087,
#  '▁fauna': 3422,
#  'taria': 34309,
#  '▁tardi': 16781,
#  '▁때문이다': 52043,
#  '▁OC': 55432,
#  'sted': 10714,
#  '压力': 39783,
#  '경': 51884,
#  '▁tecnico': 517,
#  '▁ыры': 17803,
#  'Magazin': 26966,
#  '▁Fox': 42677,
#  '▁ekologisk': 23557,
#  '▁Mess': 42380,
#  '▁ställa': 4001,
#  'alda': 42544,
#  '▁cont': 26811,
#  'するのは': 50126,
#  '職業': 45187,
#  '▁Satversme': 27696,
#  '▁παιχνίδια': 11494,
#  'āli': 13209,
#  '▁heldu': 2733,
#  '▁Fa': 35959,
#  '▁이르': 7435,
#  '▁character': 47054,
#  '锴': 32559,
#  '的人': 38277,
#  '的角度': 53805,
#  '▁şartları': 19515,
#  '▁Kid': 50940,
#  '▁المدير': 4600,
#  '宍': 32579,
#  '悸': 29555,
#  '▁romantic': 52122,
#  '▁Dyna': 50245,
#  '꿇': 33501,
#  '检察': 8335,
#  '佶': 32614,
#  '▁Kort': 36576,
#  '▁храма': 5599,
#  '开心': 51400,
#  '▁scopuri': 22899,
#  'spin': 49512,
#  '▁motiva': 35547,
#  'wind': 43246,
#  '▁miser': 51124,
#  '▁Über': 14294,
#  '▁идеята': 14395,
#  'axe': 42770,
#  'guar': 54815,
#  '▁Vader': 6966,
#  'AMI': 42049,
#  '▁ihtiyacınız': 25565,
#  'lux': 44962,
#  'pakai': 17151,
#  '弹': 38640,
#  'ʻ': 45573,
#  '鬥': 276,
#  'qin': 39533,
#  '감': 7713,
#  'പ്പെടും': 22390,
#  '肄': 33131,
#  '的服务': 49640,
#  '返': 13063,
#  'kro': 14991,
#  'Gro': 10940,
#  '氷': 28717,
#  '▁проверя': 1008,
#  '帝国': 11364,
#  'ian': 37264,
#  'rle': 50545,
#  '▁시점': 19534,
#  '▁რუ': 1316,
#  '▁lapte': 2817,
#  '儿': 10315,
#  '▁நடக்கும்': 22597,
#  'stamine': 54978,
#  '▁#': 41882,
#  'round': 48537,
#  'Stat': 8648,
#  '▁müdafiəsi': 19615,
#  'phen': 54446,
#  'TION': 37805,
#  '▁Charge': 21193,
#  '▁skuad': 3061,
#  '▁Argentina': 37406,
#  '▁yen': 34322,
#  '趾': 29363,
#  '▁understood': 25050,
#  '▁Temp': 38628,
#  '▁Bali': 35006,
#  '▁Dark': 42906,
#  '▁iluminación': 25479,
#  'iniuose': 4272,
#  'SAR': 52308,
#  'ອ່ານ': 10726,
#  '▁KW': 54767,
#  '출장아가씨': 26855,
#  'gos': 54351,
#  'ぐらい': 54805,
#  '▁రాత్రి': 5717,
#  '绵': 22614,
#  ':': 2586,
#  '▁Gör': 35128,
#  '▁views': 16019,
#  '▁Szkole': 13062,
#  '명을': 54491,
#  '電子': 23200,
#  '▁sẹo': 27709,
#  '粑': 31040,
#  '▁Leia': 5065,
#  '▁παραγωγή': 13327,
#  '▁première': 20472,
#  'ເວັບໄຊທ໌': 18505,
#  '▁Tio': 42232,
#  'Џ': 6439,
#  '▁приложения': 29,
#  'szony': 5048,
#  '▁Indonesia': 38834,
#  '▁forberede': 21195,
#  '▁Liv': 37731,
#  'reo': 41852,
#  '危险': 46563,
#  '▁수상': 53955,
#  'adat': 48862,
#  '였': 49108,
#  '▁mas': 4123,
#  '▁estabelece': 10975,
#  '区': 38182,
#  '▁Image': 26623,
#  '<unk>': 3,
#  '烊': 33611,
#  '了很多': 42705,
#  'メートル': 25374,
#  'wch': 55818,
#  '掖': 30778,
#  '기업': 38442,
#  '▁Mek': 53305,
#  '我是': 35166,
#  '收藏': 50006,
#  'حکومت': 22979,
#  '语': 4722,
#  '▁øyne': 9265,
#  '▁маси': 13121,
#  '憊': 29569,
#  '▁terse': 51529,
#  '吨': 58120,
#  'ବତୀ': 22361,
#  'fta': 37818,
#  '開発': 42144,
#  'eggia': 48379,
#  '恿': 30515,
#  'președinte': 19141,
#  '\ue002': 29484,
#  'itä': 7709,
#  'традиционал': 23213,
#  '▁Օրինակ': 27066,
#  '▁dofinansowanie': 28816,
#  'centr': 41948,
#  'ੈਂਟ': 15225,
#  'īrā': 23064,
#  '饒': 29071,
#  '▁ფაქტო': 18557,
#  '消費': 40261,
#  '济': 57770,
#  '宁': 35727,
#  'right': 44561,
#  '▁quite': 36683,
#  'Ang': 44093,
#  'bene': 42374,
#  '▁preguntar': 9421,
#  'hü': 46594,
#  '▁따라서': 53344,
#  '洒': 58066,
#  '👑': 29865,
#  '貅': 31861,
#  '喲': 30075,
#  '▁totam': 4562,
#  '▁моменти': 777,
#  'のが': 5465,
#  '▁matur': 35116,
#  '냑': 31957,
#  'gry': 42080,
#  '▁주장': 53710,
#  '台': 36871,
#  '▁ah': 6581,
#  'ကြ်န္': 26185,
#  'ST': 53651,
#  '▁favorite': 39641,
#  'sker': 36559,
#  '▁bili': 51588,
#  '▁Pan': 40864,
#  'skripsi': 5597,
#  '▁Maqal': 20131,
#  '▁호텔': 7673,
#  'とても': 25839,
#  '▁restauration': 24115,
#  '的故事': 39191,
#  '▁részlet': 10457,
#  'boleh': 57138,
#  '铿': 58168,
#  'ת': 46455,
#  '受': 41174,
#  'resh': 1322,
#  '与': 4743,
#  '▁참여': 38810,
#  '▁철': 51149,
#  '▁الإرهابية': 23196,
#  '▁venkovní': 24771,
#  '▁याच': 2900,
#  'dium': 35234,
#  'how': 42075,
#  'zum': 48819,
#  'なって': 54974,
#  'lå': 53242,
#  'Ο': 58864,
#  '▁новац': 12286,
#  '食材': 48249,
#  '集团': 12328,
#  '▁Mare': 25781,
#  '▁காட்டி': 17044,
#  '▁Saj': 41066,
#  'wand': 28191,
#  '▁piante': 17182,
#  '▁Ayo': 10108,
#  '旯': 32305,
#  '▁ശിവ': 9584,
#  '▁influência': 20008,
#  '▁Gol': 29645,
#  '▁Dinge': 44834,
#  'tur': 57140,
#  '▁шт': 57435,
#  '▓': 30375,
#  '私が': 40457,
#  '因素': 23080,
#  '▁krah': 3672,
#  '糟': 17189,
#  'HAN': 28863,
#  '筆者': 12895,
#  '▁Pon': 20909,
#  '▁97': 11532,
#  '▁деңгейде': 14293,
#  '严峻': 26522,
#  'സമ്പ': 8455,
#  'suhde': 5060,
#  'ärt': 46997,
#  '▁nick': 7192,
#  'ðu': 4092,
#  'dores': 51276,
#  '哪个': 6941,
#  'GRA': 52597,
#  'tion': 8888,
#  'undan': 37869,
#  '▁голосования': 27064,
#  'fig': 53204,
#  '▁personal': 37189,
#  '停下': 23142,
#  '▁broses': 15830,
#  '/7': 36737,
#  '慧': 56689,
#  '▁terapija': 18367,
#  '罐': 57704,
#  '▁gyventojai': 16514,
#  '驷': 32344,
#  '\uf03c': 31436,
#  '削除': 5119,
#  'mpi': 3484,
#  '▁લઇ': 7765,
#  '▁объединен': 12700,
#  '蠹': 32908,
#  'な': 7624,
#  '▁maksaa': 1986,
#  'മാക്ക': 190,
#  '▁místa': 1711,
#  '▁نماد': 14558,
#  '强': 48372,
#  'International': 7497,
#  'pest': 3513,
#  '日的': 55252,
#  'zat': 753,
#  'cking': 40031,
#  '▁dječak': 20927,
#  '▁comes': 36781,
#  '▁1966': 38184,
#  '來了': 3621,
#  '▁hinsichtlich': 25821,
#  'gó': 57497,
#  '▁aunty': 22272,
#  '脯': 30392,
#  '▁felicitat': 21329,
#  'สอด': 21779,
#  'labas': 48081,
#  'しながら': 45549,
#  '▁nemocnice': 8550,
#  '预期': 51087,
#  '価格': 37190,
#  ...}
